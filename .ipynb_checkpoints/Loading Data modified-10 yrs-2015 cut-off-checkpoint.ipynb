# %%
import requests
import time
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import os

# %%
from sqlalchemy import create_engine, inspect

# %%
from datetime import timedelta

# %%
from patsy import dmatrices

from sklearn import linear_model as lm
from sklearn.linear_model import LogisticRegression
from sklearn import cross_validation
from sklearn import metrics
from sklearn.metrics import confusion_matrix
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.metrics import roc_curve, auc

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn import pipeline, preprocessing

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn import naive_bayes
from sklearn.metrics import accuracy_score, classification_report

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
adq=pd.read_csv('./data/acquisitions.csv',encoding = "ISO-8859-1")

# %%
adq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18968 entries, 0 to 18967
# Data columns (total 18 columns):
# company_permalink         18968 non-null object
# company_name              18968 non-null object
# company_category_list     13985 non-null object
# company_country_code      14300 non-null object
# company_state_code        14020 non-null object
# company_region            14058 non-null object
# company_city              14058 non-null object
# acquirer_permalink        18968 non-null object
# acquirer_name             18968 non-null object
# acquirer_category_list    16580 non-null object
# acquirer_country_code     17798 non-null object
# acquirer_state_code       17533 non-null object
# acquirer_region           17609 non-null object
# acquirer_city             17609 non-null object
# acquired_at               18956 non-null object
# acquired_month            18954 non-null object
# price_amount              5012 non-null float64
# price_currency_code       18962 non-null object
# dtypes: float64(1), object(17)
# memory usage: 2.6+ MB

# %%
comp=pd.read_csv('./data/companies.csv',encoding = "ISO-8859-1")

# %%
comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 14 columns):
# permalink            66368 non-null object
# name                 66367 non-null object
# homepage_url         61310 non-null object
# category_list        63220 non-null object
# funding_total_usd    66368 non-null object
# status               66368 non-null object
# country_code         59410 non-null object
# state_code           57821 non-null object
# region               58338 non-null object
# city                 58340 non-null object
# funding_rounds       66368 non-null int64
# founded_at           51147 non-null object
# first_funding_at     66344 non-null object
# last_funding_at      66368 non-null object
# dtypes: int64(1), object(13)
# memory usage: 7.1+ MB

# %%
comp2=comp

# %%
ind=comp2[comp2['founded_at']=='1015-01-30'].index

# %%
comp2['founded_at'].iloc[ind]='2015-01-30'
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
ind=comp2[comp2['founded_at']=='1636-09-08'].index

# %%
comp2=comp2.drop(index=ind)

# %%
ind=comp2[comp2['founded_at']=='2914-01-01'].index
comp2['founded_at'].iloc[ind]='2014-01-01'
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
ind=comp2[comp2['founded_at']=='2914-01-01'].index
comp2=comp2.drop(index=ind)

# %%
ind=comp2[comp2['founded_at']=='1592-01-01'].index
comp2=comp2.drop(index=ind)

# %%
comp2['founded_at']=pd.to_datetime(comp2['founded_at'])

# %%
comp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66365 entries, 0 to 66367
# Data columns (total 14 columns):
# permalink            66365 non-null object
# name                 66364 non-null object
# homepage_url         61307 non-null object
# category_list        63217 non-null object
# funding_total_usd    66365 non-null object
# status               66365 non-null object
# country_code         59409 non-null object
# state_code           57820 non-null object
# region               58337 non-null object
# city                 58339 non-null object
# funding_rounds       66365 non-null int64
# founded_at           51144 non-null datetime64[ns]
# first_funding_at     66341 non-null object
# last_funding_at      66365 non-null object
# dtypes: datetime64[ns](1), int64(1), object(12)
# memory usage: 7.6+ MB

# %%
ind=comp2[comp2['founded_at']>'2015-12-04 00:00:00'].index
comp2=comp2.drop(index=ind)

# %%
# the data was extracted from the December 4, 2015
comp2['founded_at'].max()
# Out:
# Timestamp('2015-12-01 00:00:00')

# %%
ind=comp[comp['founded_at']=='1015-01-30'].index
comp['founded_at'].iloc[ind]='2015-01-30'
ind=comp[comp['founded_at']=='1636-09-08'].index
comp=comp.drop(index=ind)
ind=comp[comp['founded_at']=='2914-01-01'].index
comp['founded_at'].iloc[ind]='2014-01-01'
ind=comp[comp['founded_at']=='2914-01-01'].index
comp=comp.drop(index=ind)
ind=comp[comp['founded_at']=='1592-01-01'].index
comp=comp.drop(index=ind)
comp['founded_at']=pd.to_datetime(comp['founded_at'])
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#date for database snapshot
reft='2015-12-04 00:00:00'

# %%
reft=pd.Series({'reft':reft})

# %%
reft=pd.to_datetime(reft)

# %%
reft[0]
# Out:
# Timestamp('2015-12-04 00:00:00')

# %%
comp2=comp2.dropna(subset=['status', 'founded_at'])

# %%
comp2['days_in_op']=reft[0]-comp2['founded_at']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
comp2[['days_in_op','founded_at']][:10]
# Out:
#    days_in_op founded_at
# 1    456 days 2014-09-04
# 3   3259 days 2007-01-01
# 4   2163 days 2010-01-01
# 6   6911 days 1997-01-01
# 7   1798 days 2011-01-01
# 8   1586 days 2011-08-01
# 9   1433 days 2012-01-01
# 11   727 days 2013-12-07
# 12 10929 days 1986-01-01
# 13 11660 days 1984-01-01

# %%
comp2['days_in_op']=comp2['days_in_op'].astype('timedelta64[D]')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
10*365
# Out:
# 3650

# %%
comp2= comp2[comp2['days_in_op']>3650]

# %%
comp2['days_in_op'].describe()
# Out:
# count    13542.000000
# mean      6536.192660
# std       5836.349306
# min       3286.000000
# 25%       3989.000000
# 50%       5085.000000
# 75%       6546.000000
# max      97491.000000
# Name: days_in_op, dtype: float64

# %%
comp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11581 entries, 6 to 66358
# Data columns (total 17 columns):
# permalink                11581 non-null object
# company_name             11581 non-null object
# homepage_url             10641 non-null object
# category_list            11197 non-null object
# funding_total_usd        11581 non-null object
# status                   11581 non-null object
# country_code             11121 non-null object
# state_code               10982 non-null object
# region                   10992 non-null object
# city                     10993 non-null object
# funding_rounds           11581 non-null int64
# founded_at               11581 non-null datetime64[ns]
# first_funding_at         11581 non-null datetime64[ns]
# last_funding_at          11581 non-null datetime64[ns]
# days_in_op               11581 non-null float64
# first_funding_dayinop    11581 non-null timedelta64[ns]
# last_funding_dayinop     11581 non-null timedelta64[ns]
# dtypes: datetime64[ns](3), float64(1), int64(1), object(10), timedelta64[ns](2)
# memory usage: 1.6+ MB

# %%
comp2['first_funding_at']=pd.to_datetime(comp2['first_funding_at'])

# %%
comp2['last_funding_at']=pd.to_datetime(comp2['last_funding_at'])

# %%
comp2['first_funding_dayinop']=comp2['first_funding_at']-comp2['founded_at']

# %%
comp2['last_funding_dayinop']=comp2['last_funding_at']-comp2['founded_at']

# %%
comp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13542 entries, 6 to 66358
# Data columns (total 17 columns):
# permalink                13542 non-null object
# name                     13542 non-null object
# homepage_url             12521 non-null object
# category_list            13127 non-null object
# funding_total_usd        13542 non-null object
# status                   13542 non-null object
# country_code             13017 non-null object
# state_code               12852 non-null object
# region                   12874 non-null object
# city                     12875 non-null object
# funding_rounds           13542 non-null int64
# founded_at               13542 non-null datetime64[ns]
# first_funding_at         13542 non-null datetime64[ns]
# last_funding_at          13542 non-null datetime64[ns]
# days_in_op               13542 non-null float64
# first_funding_dayinop    13542 non-null timedelta64[ns]
# last_funding_dayinop     13542 non-null timedelta64[ns]
# dtypes: datetime64[ns](3), float64(1), int64(1), object(10), timedelta64[ns](2)
# memory usage: 1.9+ MB

# %%
ind=comp2[comp2['first_funding_dayinop'].isnull()].index

# %%
comp2
# Out:
#                                   permalink                      name  \
# 6       /organization/0ndine-biomedical-inc    Ondine Biomedical Inc.
# 12              /organization/1-800-dentist             1-800-DENTIST
# 13              /organization/1-800-doctors             1-800-DOCTORS
# 17                /organization/10-20-media               10-20 Media
# 32                   /organization/1010data                  1010data
# 57               /organization/123greetings              123Greetings
# 75          /organization/16-mile-solutions         16 Mile Solutions
# 80                /organization/170-systems               170 Systems
# 82                     /organization/17u-cn                    17u.cn
# 87                      /organization/19pay                     19pay
# 88                       /organization/1bib                      1bib
# 90                 /organization/1c-company                1C Company
# 92                      /organization/1cast                     1Cast
# 106          /organization/1life-healthcare          1Life Healthcare
# 118                   /organization/1stdibs                   1stdibs
# 123                 /organization/2-minutes                 2 Minutes
# 127    /organization/20-20-gene-systems-inc   20/20 Gene Systems Inc.
# 128              /organization/20-20-mobile              20:20 Mobile
# 134            /organization/21cake-food-co           21Cake Food Co.
# 140        /organization/22nd-century-group        22nd Century Group
# 142                  /organization/2345-com                  2345.com
# 144                   /organization/23andme                   23andMe
# 147             /organization/24-7-customer                     [24]7
# 151      /organization/247-learning-private             24x7 Learning
# 156                     /organization/24h00                     24h00
# 166               /organization/265-network               265 Network
# 172    /organization/2adpro-media-solutions    2AdPro Media Solutions
# 174                      /organization/2c2p                      2C2P
# 177             /organization/2checkout-com                 2Checkout
# 192    /organization/2nd-story-software-inc  2nd Story Software, Inc.
# ...                                     ...                       ...
# 66197                /organization/zoominfo                  ZoomInfo
# 66198                /organization/zoomingo                  Zoomingo
# 66199          /organization/zoomio-holding            Zoomio Holding
# 66206             /organization/zoomsystems               ZoomSystems
# 66213                  /organization/zooomr                    Zooomr
# 66216                 /organization/zooplus                   Zooplus
# 66223                   /organization/zoove                     Zoove
# 66226                    /organization/zopa                      Zopa
# 66235           /organization/zosano-pharma             Zosano Pharma
# 66238                  /organization/zounds                    Zounds
# 66248                  /organization/zpower                    ZPower
# 66251             /organization/zs-genetics               ZS Genetics
# 66257                   /organization/ztail                     Ztail
# 66262                 /organization/zubican                   Zubican
# 66264                   /organization/zubka                     Zubka
# 66265                  /organization/zuchem                    ZUCHEM
# 66282                 /organization/zumatek                   zumatek
# 66283           /organization/zumba-fitness             Zumba Fitness
# 66285                  /organization/zumbox                    Zumbox
# 66286               /organization/zume-life                 Zume Life
# 66321                  /organization/zvents                    Zvents
# 66327              /organization/zweitgeist                zweitgeist
# 66335                    /organization/zygo       Zygo Communications
# 66337         /organization/zyken-nightcove         Zyken - NightCove
# 66338                   /organization/zykis                     Zykis
# 66341          /organization/zyme-solutions            Zyme Solutions
# 66343                 /organization/zymetis                   Zymetis
# 66344               /organization/zymeworks                 Zymeworks
# 66355              /organization/zyomyx-inc                    ZYOMYX
# 66358        /organization/zyraz-technology          Zyraz Technology
#
#                                 homepage_url  \
# 6                       http://ondinebio.com
# 12                http://www.1800dentist.com
# 13                    http://1800doctors.com
# 17                 http://www.10-20media.com
# 32                   http://www.1010data.com
# 57              http://www.123greetings.com/
# 75                                       NaN
# 80                 http://www.170systems.com
# 82                         http://www.17u.cn
# 87                   http://www.19pay.com.cn
# 88                       http://www.1bib.com
# 90                          http://1c.ru/eng
# 92                      http://www.1cast.com
# 106                     http://www.1life.com
# 118                   http://www.1stdibs.com
# 123                   http://www.2minutes.fr
# 127                      http://2020gene.com
# 128                http://www.2020mobile.com
# 134                    http://www.21cake.com
# 140               http://www.xxiicentury.com
# 142                      http://www.2345.com
# 144                       http://23andme.com
# 147                       http://247-inc.com
# 151              http://www.24x7learning.com
# 156                  http://www.boosket.com/
# 166                       http://www.265.com
# 172                    http://www.2adpro.com
# 174                      http://www.2c2p.com
# 177                 http://www.2checkout.com
# 192                    http://www.taxact.com
# ...                                      ...
# 66197                http://www.zoominfo.com
# 66198                http://www.zoomingo.com
# 66199                  http://www.zoomio.com
# 66206             http://www.zoomsystems.com
# 66213                      http://zooomr.com
# 66216                  http://www.zooplus.de
# 66223                       http://zoove.com
# 66226                    http://www.zopa.com
# 66235                http://zosanopharma.com
# 66238           http://www.zoundshearing.com
# 66248    http://zpowerbattery.com/index.html
# 66251              http://www.zsgenetics.com
# 66257                       http://ztail.com
# 66262                 http://www.zubican.com
# 66264                   http://www.zubka.com
# 66265                  http://www.zuchem.com
# 66282                     http://zumatek.com
# 66283                   http://www.zumba.com
# 66285                https://www.zumbox.com/
# 66286                http://www.zumelife.com
# 66321                  http://www.zvents.com
# 66327                  http://www.weblin.com
# 66335  http://www.zygocommunications.com/who
# 66337                   http://www.zyken.com
# 66338                       http://zykis.com
# 66341           http://www.zymesolutions.com
# 66343                 http://www.zymetis.com
# 66344                   http://zymeworks.com
# 66355                  http://www.zyomyx.com
# 66358                   http://www.zyraz.com
#
#                                            category_list funding_total_usd  \
# 6                                          Biotechnology            762851
# 12                                   Health and Wellness                 -
# 13                                   Health and Wellness           1750000
# 17                                            E-Commerce           2050000
# 32                                              Software          35000000
# 57                                              Internet           5400000
# 75                                              Software            199957
# 80                                              Software          14000000
# 82                                                Travel          84440319
# 87                                       Finance|FinTech           9478511
# 88                                      Cars|Curated Web                 -
# 90                            Games|Software|Video Games         200000000
# 92                          Content|Lifestyle|News|Video                 -
# 106             Health and Wellness|Health Care|Services          30000000
# 118                                           E-Commerce         117000000
# 123                                                Games           1660000
# 127                     Biotechnology|Health Diagnostics           4345427
# 128                                               Mobile          29750000
# 134                   Delivery|Hospitality|Manufacturing           1464128
# 140                                        Biotechnology          15034750
# 142                                             Software           1610541
# 144                                 Biotechnology|Search         227049900
# 147    Customer Service|Predictive Analytics|Services...                 -
# 151                             EdTech|Education|Systems           4000000
# 156          Advertising|E-Commerce|Marketing Automation                 -
# 166                                             Software           2000000
# 172    Ad Targeting|Advertising|Advertising Platforms...                 -
# 174         E-Commerce|Mobile Commerce|Payments|Software          10000000
# 177                                           E-Commerce          72000000
# 192                                             Software          85000000
# ...                                                  ...               ...
# 66197  Big Data Analytics|Business Services|Contact M...           7000000
# 66198                                   E-Commerce|Games           2475000
# 66199                                           Software           7130000
# 66206                                Hardware + Software          87000000
# 66213               Curated Web|File Sharing|Photography             50000
# 66216                                       Pets|Trading                 -
# 66223                   Advertising|App Marketing|Mobile          59139710
# 66226                                    Finance|FinTech          56628771
# 66235                                      Biotechnology         158688887
# 66238  Batteries|Email|Forums|Franchises|Hardware + S...          73166307
# 66248         Batteries|Clean Technology|Medical Devices         133437465
# 66251                                      Biotechnology           2614963
# 66257                        E-Commerce|Price Comparison           1500000
# 66262     B2B|Curated Web|Internet Marketing|Procurement                 -
# 66264                                         Consulting  3919186.37690815
# 66265                                Health and Wellness            150000
# 66282                                      Biotechnology            150000
# 66283                                Health and Wellness                 -
# 66285                               Curated Web|Internet          28300000
# 66286  Health and Wellness|iPhone|Mobile|Social Netwo...           1700000
# 66321  Concerts|Curated Web|Entertainment|Events|Kids...          55200000
# 66327                                 Messaging|Software            651000
# 66335                                         Mobile|SMS                 -
# 66337     Design|Hardware + Software|Health and Wellness           3384225
# 66338  Automotive|Data Security|Education|Kids|Portal...            800000
# 66341                       Hardware|Hardware + Software          12039999
# 66343                                      Biotechnology           2257464
# 66344                                      Biotechnology          64674400
# 66355                                      Biotechnology          34275015
# 66358                                      Biotechnology          15419877
#
#           status country_code state_code            region  \
# 6      operating          CAN         BC         Vancouver
# 12     operating          USA         CA       Los Angeles
# 13     operating          USA         NJ            Newark
# 17     operating          USA         MD         Baltimore
# 32      acquired          USA         NY     New York City
# 57     operating          NaN        NaN               NaN
# 75     operating          USA         WA           Seattle
# 80      acquired          USA         MA            Boston
# 82     operating          CHN          4          Shanghai
# 87     operating          CHN         22           Beijing
# 88        closed          CHN         30         Guangzhou
# 90        closed          RUS         48            Moscow
# 92        closed          USA         WA           Seattle
# 106    operating          USA         CA       SF Bay Area
# 118    operating          USA         NY     New York City
# 123    operating          FRA         A8             Paris
# 127    operating          USA         MD  Washington, D.C.
# 128    operating          IRL         23       IRL - Other
# 134    operating          CHN         22           Beijing
# 140          ipo          USA         NY        NY - Other
# 142    operating          CHN         23          Shanghai
# 144    operating          USA         CA       SF Bay Area
# 147    operating          USA         CA       SF Bay Area
# 151    operating          IND         19         Bangalore
# 156       closed          FRA         A8             Paris
# 166    operating          CHN         22           Beijing
# 172    operating          USA         CA       Los Angeles
# 174    operating          SGP        NaN               NaN
# 177    operating          USA         OH    Columbus, Ohio
# 192     acquired          USA         IA      Cedar Rapids
# ...          ...          ...        ...               ...
# 66197  operating          USA         MA            Boston
# 66198  operating          USA         WA           Seattle
# 66199   acquired          DNK         17        Copenhagen
# 66206  operating          USA         CA       SF Bay Area
# 66213     closed          USA         CA       SF Bay Area
# 66216        ipo          DEU          2          Muenchen
# 66223   acquired          USA         NY     New York City
# 66226  operating          GBR         H9            London
# 66235        ipo          USA         CA       SF Bay Area
# 66238  operating          USA         AZ           Phoenix
# 66248  operating          USA         CA     Santa Barbara
# 66251  operating          USA         MA            Boston
# 66257     closed          USA         CA       SF Bay Area
# 66262   acquired          USA         CA     Santa Barbara
# 66264     closed          GBR         B9               NaN
# 66265  operating          USA         IL           Chicago
# 66282  operating          USA         NC           Raleigh
# 66283  operating          USA         FL        FL - Other
# 66285     closed          USA         CA       Los Angeles
# 66286     closed          USA         CA       SF Bay Area
# 66321   acquired          USA         CA       SF Bay Area
# 66327  operating          DEU          4           Hamburg
# 66335     closed          GBR         H9            London
# 66337   acquired          FRA         A8             Paris
# 66338     closed          USA         CA           Anaheim
# 66341  operating          USA         CA       SF Bay Area
# 66343     closed          USA         MD  Washington, D.C.
# 66344  operating          CAN         BC         Vancouver
# 66355  operating          USA         MO        MO - Other
# 66358     closed          MYS         14       MYS - Other
#
#                         city  funding_rounds founded_at first_funding_at  \
# 6                  Vancouver               2 1997-01-01       2009-09-11
# 12               Los Angeles               1 1986-01-01       2010-08-19
# 13                    Iselin               1 1984-01-01       2011-03-02
# 17                  Woodbine               4 2001-01-01       2009-06-18
# 32                  New York               1 2000-01-01       2010-03-08
# 57                       NaN               1 1997-05-01       2015-07-23
# 75                   Seattle               1 2006-01-01       2009-06-11
# 80                   Bedford               1 1990-01-01       2002-04-16
# 82                    Suzhou               3 2004-01-01       2008-01-01
# 87                   Beijing               3 2005-01-01       2006-01-01
# 88                 Guangzhou               1 2006-01-01       2008-02-07
# 90                    Moscow               1 1991-01-01       2011-10-03
# 92                  Kirkland               1 2006-06-01       2008-08-12
# 106            San Francisco               1 2002-01-01       2013-03-21
# 118                 New York               5 2001-01-01       2011-11-03
# 123                    Paris               1 2000-10-01       2008-06-19
# 127                Rockville               3 2000-05-01       2012-09-25
# 128                     Cree               1 2006-09-01       2008-07-04
# 134                  Beijing               1 2004-01-01       2010-01-22
# 140                 Clarence               6 1998-01-01       2010-12-28
# 142                 Shanghai               2 2005-09-01       2010-05-01
# 144            Mountain View               8 2006-04-01       2005-11-02
# 147                 Campbell               1 2000-04-01       2003-07-01
# 151                Bangalore               1 2001-01-01       2007-11-06
# 156                    Paris               1 2006-01-01       2006-08-01
# 166                  Beijing               1 2004-01-01       2004-12-01
# 172           Woodland Hills               1 2006-09-01       2008-03-31
# 174                      NaN               3 2003-01-01       2011-01-01
# 177                 Columbus               2 1999-01-01       2014-07-16
# 192             Cedar Rapids               1 1998-02-15       2005-03-30
# ...                      ...             ...        ...              ...
# 66197                Waltham               1 2000-02-01       2004-07-01
# 66198               Bellevue               2 2000-01-01       2013-11-01
# 66199             Copenhagen               1 2002-01-01       2007-12-19
# 66206          San Francisco               5 2002-01-01       2005-07-19
# 66213          San Francisco               1 2006-03-01       2006-02-01
# 66216               Muenchen               1 1999-01-01       2000-01-01
# 66223               New York               7 2004-03-01       2006-06-20
# 66226                 London               6 2005-03-01       2005-01-01
# 66235                Fremont               9 2006-10-01       2007-11-15
# 66238                Phoenix               4 2005-01-01       2007-02-14
# 66248              Camarillo               8 1996-01-01       2004-10-12
# 66251              Wakefield               4 2005-01-01       2012-01-06
# 66257              Palo Alto               2 2005-01-01       2008-05-01
# 66262               Moorpark               1 2006-12-01       2008-05-01
# 66264                    NaN               1 2006-01-01       2007-02-09
# 66265                Chicago               1 2001-01-01       2013-04-16
# 66282            Chapel Hill               1 2005-01-01       2010-11-23
# 66283             Hallandale               1 2001-01-01       2012-03-08
# 66285            Los Angeles               4 2006-10-01       2008-06-23
# 66286               San Jose               2 2006-07-25       2007-01-01
# 66321              San Mateo               4 2005-03-01       2005-10-05
# 66327                Hamburg               1 2006-06-24       2007-02-01
# 66335                 London               1 2005-06-21       2007-11-19
# 66337                  Paris               4 2005-01-01       2005-01-01
# 66338                 Irvine               1 2006-10-27       2006-10-27
# 66341         Redwood Shores               5 2004-01-01       2005-09-12
# 66343           College Park               3 2006-01-01       2007-01-01
# 66344              Vancouver               7 2004-04-01       2008-03-03
# 66355                Fremont               4 1998-01-01       2010-01-29
# 66358  Damansara New Village               4 1994-01-01       2008-01-01
#
#       last_funding_at  days_in_op first_funding_dayinop last_funding_dayinop
# 6          2009-12-21      6911.0             4636 days            4737 days
# 12         2010-08-19     10929.0             8996 days            8996 days
# 13         2011-03-02     11660.0             9922 days            9922 days
# 17         2011-12-28      5450.0             3090 days            4013 days
# 32         2010-03-08      5816.0             3719 days            3719 days
# 57         2015-07-23      6791.0             6657 days            6657 days
# 75         2009-06-11      3624.0             1257 days            1257 days
# 80         2002-04-16      9468.0             4488 days            4488 days
# 82         2014-02-17      4355.0             1461 days            3700 days
# 87         2013-07-01      3989.0              365 days            3103 days
# 88         2008-02-07      3624.0              767 days             767 days
# 90         2011-10-03      9103.0             7580 days            7580 days
# 92         2008-08-12      3473.0              803 days             803 days
# 106        2013-03-21      5085.0             4097 days            4097 days
# 118        2015-09-09      5450.0             3958 days            5364 days
# 123        2008-06-19      5542.0             2818 days            2818 days
# 127        2015-10-30      5695.0             4530 days            5660 days
# 128        2008-07-04      3381.0              672 days             672 days
# 134        2010-01-22      4355.0             2213 days            2213 days
# 140        2014-09-18      6546.0             4744 days            6104 days
# 142        2010-10-01      3746.0             1703 days            1856 days
# 144        2015-07-03      3534.0             -150 days            3380 days
# 147        2003-07-01      5725.0             1186 days            1186 days
# 151        2007-11-06      5450.0             2500 days            2500 days
# 156        2006-08-01      3624.0              212 days             212 days
# 166        2004-12-01      4355.0              335 days             335 days
# 172        2008-03-31      3381.0              577 days             577 days
# 174        2015-04-27      4720.0             2922 days            4499 days
# 177        2015-09-15      6181.0             5675 days            6101 days
# 192        2005-03-30      6501.0             2600 days            2600 days
# ...               ...         ...                   ...                  ...
# 66197      2004-07-01      5785.0             1612 days            1612 days
# 66198      2013-11-05      5816.0             5053 days            5057 days
# 66199      2007-12-19      5085.0             2178 days            2178 days
# 66206      2010-01-14      5085.0             1295 days            2935 days
# 66213      2006-02-01      3565.0              -28 days             -28 days
# 66216      2000-01-01      6181.0              365 days             365 days
# 66223      2014-03-05      4295.0              841 days            3656 days
# 66226      2014-01-29      3930.0              -59 days            3256 days
# 66235      2015-02-03      3351.0              410 days            3047 days
# 66238      2011-11-09      3989.0              774 days            2503 days
# 66248      2014-05-28      7277.0             3207 days            6722 days
# 66251      2015-05-06      3989.0             2561 days            3777 days
# 66257      2009-04-01      3989.0             1216 days            1551 days
# 66262      2008-05-01      3290.0              517 days             517 days
# 66264      2007-02-09      3624.0              404 days             404 days
# 66265      2013-04-16      5450.0             4488 days            4488 days
# 66282      2010-11-23      3989.0             2152 days            2152 days
# 66283      2012-03-08      5450.0             4084 days            4084 days
# 66285      2012-07-10      3351.0              631 days            2109 days
# 66286      2008-04-01      3419.0              160 days             616 days
# 66321      2011-09-30      3930.0              218 days            2404 days
# 66327      2007-02-01      3450.0              222 days             222 days
# 66335      2007-11-19      3818.0              881 days             881 days
# 66337      2012-04-01      3989.0                0 days            2647 days
# 66338      2006-10-27      3325.0                0 days               0 days
# 66341      2014-05-01      4355.0              620 days            3773 days
# 66343      2010-01-31      3624.0              365 days            1491 days
# 66344      2015-02-27      4264.0             1432 days            3984 days
# 66355      2014-03-26      6546.0             4411 days            5928 days
# 66358      2013-02-15      8007.0             5113 days            6985 days
#
# [13542 rows x 17 columns]

# %%
comp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13542 entries, 6 to 66358
# Data columns (total 17 columns):
# permalink                13542 non-null object
# name                     13542 non-null object
# homepage_url             12521 non-null object
# category_list            13127 non-null object
# funding_total_usd        13542 non-null object
# status                   13542 non-null object
# country_code             13017 non-null object
# state_code               12852 non-null object
# region                   12874 non-null object
# city                     12875 non-null object
# funding_rounds           13542 non-null int64
# founded_at               13542 non-null datetime64[ns]
# first_funding_at         13542 non-null datetime64[ns]
# last_funding_at          13542 non-null datetime64[ns]
# days_in_op               13542 non-null float64
# first_funding_dayinop    13542 non-null timedelta64[ns]
# last_funding_dayinop     13542 non-null timedelta64[ns]
# dtypes: datetime64[ns](3), float64(1), int64(1), object(10), timedelta64[ns](2)
# memory usage: 1.9+ MB

# %%
invs=pd.read_csv('./data/crunchbase-investments.csv',encoding = "ISO-8859-1")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
invs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52870 entries, 0 to 52869
# Data columns (total 20 columns):
# company_permalink         52869 non-null object
# company_name              52869 non-null object
# company_category_code     52227 non-null object
# company_country_code      52869 non-null object
# company_state_code        52378 non-null object
# company_region            52869 non-null object
# company_city              52337 non-null object
# investor_permalink        52868 non-null object
# investor_name             52868 non-null object
# investor_category_code    2443 non-null object
# investor_country_code     40869 non-null object
# investor_state_code       36061 non-null object
# investor_region           52868 non-null object
# investor_city             40390 non-null object
# funding_round_type        52867 non-null object
# funded_at                 52867 non-null object
# funded_month              52867 non-null object
# funded_quarter            52867 non-null object
# funded_year               52867 non-null float64
# raised_amount_usd         49271 non-null float64
# dtypes: float64(2), object(18)
# memory usage: 8.1+ MB

# %%
invs['investor_category_code'].unique()
# Out:
# array([nan, 'finance', 'web', 'nanotech', 'cleantech', 'biotech', 'other',
#        'consulting', 'education', 'nonprofit', 'hardware', 'games_video',
#        'software', 'advertising', 'security', 'public_relations',
#        'semiconductor', 'ecommerce', 'enterprise', 'mobile',
#        'network_hosting', 'social', 'news', 'legal', 'medical', 'search',
#        'health', 'government', 'pets', 'manufacturing', 'fashion',
#        'messaging', 'real_estate', 'transportation'], dtype=object)

# %%
rds=pd.read_csv('./data/crunchbase-rounds.csv',encoding = "ISO-8859-1")

# %%
rds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31679 entries, 0 to 31678
# Data columns (total 13 columns):
# company_permalink        31679 non-null object
# company_name             31679 non-null object
# company_category_code    31215 non-null object
# company_country_code     31679 non-null object
# company_state_code       31334 non-null object
# company_region           31679 non-null object
# company_city             31329 non-null object
# funding_round_type       31679 non-null object
# funded_at                31679 non-null object
# funded_month             31679 non-null object
# funded_quarter           31679 non-null object
# funded_year              31679 non-null int64
# raised_amount_usd        29100 non-null float64
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.1+ MB

# %%
rds['funded_at']=pd.to_datetime(rds['funded_at'])

# %%
comp.shape
# Out:
# (66368, 14)

# %%
invs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52870 entries, 0 to 52869
# Data columns (total 20 columns):
# company_permalink         52869 non-null object
# company_name              52869 non-null object
# company_category_code     52227 non-null object
# company_country_code      52869 non-null object
# company_state_code        52378 non-null object
# company_region            52869 non-null object
# company_city              52337 non-null object
# investor_permalink        52868 non-null object
# investor_name             52868 non-null object
# investor_category_code    2443 non-null object
# investor_country_code     40869 non-null object
# investor_state_code       36061 non-null object
# investor_region           52868 non-null object
# investor_city             40390 non-null object
# funding_round_type        52867 non-null object
# funded_at                 52867 non-null object
# funded_month              52867 non-null object
# funded_quarter            52867 non-null object
# funded_year               52867 non-null float64
# raised_amount_usd         49271 non-null float64
# dtypes: float64(2), object(18)
# memory usage: 8.1+ MB

# %%
invs[:10]
# Out:
#      company_permalink company_name company_category_code  \
# 0    /company/advercar     AdverCar           advertising
# 1  /company/launchgram   LaunchGram                  news
# 2        /company/utap         uTaP             messaging
# 3    /company/zoopshop     ZoopShop              software
# 4    /company/efuneral     eFuneral                   web
# 5       /company/tackk        Tackk                   web
# 6    /company/acclaimd     Acclaimd             analytics
# 7    /company/acclaimd     Acclaimd             analytics
# 8    /company/toviefor     ToVieFor             ecommerce
# 9    /company/ohk-labs     OHK Labs                sports
#
#   company_country_code company_state_code         company_region  \
# 0                  USA                 CA                 SF Bay
# 1                  USA                 CA                 SF Bay
# 2                  USA                NaN  United States - Other
# 3                  USA                 OH               Columbus
# 4                  USA                 OH              Cleveland
# 5                  USA                 OH              Cleveland
# 6                  USA                 OH               Columbus
# 7                  USA                 OH               Columbus
# 8                  USA                 NY               New York
# 9                  USA                 FL             Palm Beach
#
#     company_city                                 investor_permalink  \
# 0  San Francisco                         /company/1-800-flowers-com
# 1  Mountain View                               /company/10xelerator
# 2            NaN                               /company/10xelerator
# 3       columbus                               /company/10xelerator
# 4      Cleveland                               /company/10xelerator
# 5      Cleveland                               /company/10xelerator
# 6       Columbus                               /company/10xelerator
# 7       Columbus                               /company/10xelerator
# 8       New York  /company/2010-nyu-stern-business-plan-competition
# 9     Boca Raton                           /company/22hundred-group
#
#                               investor_name investor_category_code  \
# 0                         1-800-FLOWERS.COM                    NaN
# 1                               10Xelerator                finance
# 2                               10Xelerator                finance
# 3                               10Xelerator                finance
# 4                               10Xelerator                finance
# 5                               10Xelerator                finance
# 6                               10Xelerator                finance
# 7                               10Xelerator                finance
# 8  2010 NYU Stern Business Plan Competition                    NaN
# 9                           22Hundred Group                    NaN
#
#   investor_country_code investor_state_code investor_region investor_city  \
# 0                   USA                  NY        New York      New York
# 1                   USA                  OH        Columbus      Columbus
# 2                   USA                  OH        Columbus      Columbus
# 3                   USA                  OH        Columbus      Columbus
# 4                   USA                  OH        Columbus      Columbus
# 5                   USA                  OH        Columbus      Columbus
# 6                   USA                  OH        Columbus      Columbus
# 7                   USA                  OH        Columbus      Columbus
# 8                   NaN                 NaN         unknown           NaN
# 9                   NaN                 NaN         unknown           NaN
#
#   funding_round_type   funded_at funded_month funded_quarter  funded_year  \
# 0           series-a  2012-10-30      2012-10        2012-Q4       2012.0
# 1              other  2012-01-23      2012-01        2012-Q1       2012.0
# 2              other  2012-01-01      2012-01        2012-Q1       2012.0
# 3              angel  2012-02-15      2012-02        2012-Q1       2012.0
# 4              other  2011-09-08      2011-09        2011-Q3       2011.0
# 5              other  2012-02-01      2012-02        2012-Q1       2012.0
# 6              angel  2012-06-01      2012-06        2012-Q2       2012.0
# 7              angel  2012-08-07      2012-08        2012-Q3       2012.0
# 8              angel  2010-04-01      2010-04        2010-Q2       2010.0
# 9              angel  2011-09-01      2011-09        2011-Q3       2011.0
#
#    raised_amount_usd
# 0          2000000.0
# 1            20000.0
# 2            20000.0
# 3            20000.0
# 4            20000.0
# 5            20000.0
# 6            20000.0
# 7            70000.0
# 8            75000.0
# 9           100000.0

# %%
comp2.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list',
#        'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'first_funding_at',
#        'last_funding_at', 'days_in_op', 'first_funding_dayinop',
#        'last_funding_dayinop'],
#       dtype='object')

# %%
comp2.columns=['permalink', 'company_name', 'homepage_url', 'category_list',
       'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
       'city', 'funding_rounds', 'founded_at', 'first_funding_at',
       'last_funding_at', 'days_in_op', 'first_funding_dayinop',
       'last_funding_dayinop']

# %%
rds.funding_round_type.unique()
# Out:
# array(['series-a', 'angel', 'series-b', 'venture', 'other', 'series-c+',
#        'private-equity', 'post-ipo', 'crowdfunding'], dtype=object)

# %%
rds[rds['funding_round_type']=='crowdfunding'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 1831 to 30536
# Data columns (total 13 columns):
# company_permalink        30 non-null object
# company_name             30 non-null object
# company_category_code    29 non-null object
# company_country_code     30 non-null object
# company_state_code       30 non-null object
# company_region           30 non-null object
# company_city             29 non-null object
# funding_round_type       30 non-null object
# funded_at                30 non-null datetime64[ns]
# funded_month             30 non-null object
# funded_quarter           30 non-null object
# funded_year              30 non-null int64
# raised_amount_usd        29 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(10)
# memory usage: 3.3+ KB

# %%
gp=rds[rds['funding_round_type']=='crowdfunding'].groupby('company_name')

# %%
crowd=pd.DataFrame({'company_name':list(gp.groups.keys())})

# %%
crowd['funded_at']=pd.DataFrame({'funded_at':list(gp['funded_at'].min().values)})

# %%
crowd
# Out:
#                company_name  funded_at
# 0                   App.net 2012-08-12
# 1                  Appy Pie 2013-08-28
# 2      Cloud Imperium Games 2013-09-27
# 3         Dragon Innovation 2013-08-08
# 4             Elevation Lab 2012-02-11
# 5            Exposed Vocals 2013-07-16
# 6          Faraday Bicycles 2012-08-01
# 7                  Formlabs 2012-10-25
# 8                    Fuel3D 2013-09-04
# 9             Glowing Plant 2013-06-08
# 10   Good Times Restaurants 2013-08-21
# 11         Icarus Ascending 2013-09-05
# 12                LUMI Mask 2011-01-06
# 13              NOMAD GOODS 2012-08-27
# 14              NanoSatisfi 2012-07-14
# 15          OLIVERS Apparel 2013-08-30
# 16                     OUYA 2012-08-09
# 17                Oculus VR 2012-01-01
# 18         Perle Bioscience 2013-09-26
# 19                Pressgram 2013-04-15
# 20                   Pressy 2013-09-19
# 21  R.A. Burch Construction 2013-09-09
# 22               SLIC games 2012-10-01
# 23                  Scanadu 2013-06-09
# 24             TinyCircuits 2013-09-04
# 25            Upheaval Arts 2013-09-12
# 26              WealthForge 2013-08-08
# 27     Wikimedia Foundation 2008-03-01

# %%
crowd=pd.merge(crowd,rds[rds['funding_round_type']=='crowdfunding'][['company_name','funded_at','raised_amount_usd']],how='left', on=['company_name','funded_at'])

# %%
crowd
# Out:
#                company_name  funded_at  raised_amount_usd
# 0                   App.net 2012-08-12           500000.0
# 1                  Appy Pie 2013-08-28            10000.0
# 2      Cloud Imperium Games 2013-09-27         20000000.0
# 3         Dragon Innovation 2013-08-08          2145000.0
# 4             Elevation Lab 2012-02-11          1450000.0
# 5            Exposed Vocals 2013-07-16           250000.0
# 6          Faraday Bicycles 2012-08-01           177268.0
# 7                  Formlabs 2012-10-25          2800000.0
# 8                    Fuel3D 2013-09-04           325000.0
# 9             Glowing Plant 2013-06-08           484000.0
# 10   Good Times Restaurants 2013-08-21          5500000.0
# 11         Icarus Ascending 2013-09-05            10000.0
# 12                LUMI Mask 2011-01-06            27000.0
# 13              NOMAD GOODS 2012-08-27           161897.0
# 14              NanoSatisfi 2012-07-14           100000.0
# 15          OLIVERS Apparel 2013-08-30           173000.0
# 16                     OUYA 2012-08-09          8600000.0
# 17                Oculus VR 2012-01-01          2400000.0
# 18         Perle Bioscience 2013-09-26          2000000.0
# 19                Pressgram 2013-04-15            56500.0
# 20                   Pressy 2013-09-19           500000.0
# 21  R.A. Burch Construction 2013-09-09         14600000.0
# 22               SLIC games 2012-10-01            10000.0
# 23                  Scanadu 2013-06-09          1565113.0
# 24             TinyCircuits 2013-09-04           110000.0
# 25            Upheaval Arts 2013-09-12            85000.0
# 26              WealthForge 2013-08-08                NaN
# 27     Wikimedia Foundation 2008-03-01          3000000.0

# %%
crowd.columns =['company_name', 'cr_funded_at', 'cr_raised_amount_usd']

# %%
gp=rds[rds['funding_round_type']=='series-a'].groupby('company_name')
s_a=pd.DataFrame({'company_name':list(gp.groups.keys())})

# %%
gp=rds[rds['funding_round_type']=='series-a'].groupby('company_name')
s_a=pd.DataFrame({'company_name':list(gp.groups.keys())})
s_a['funded_at']=pd.DataFrame({'funded_at':list(gp['funded_at'].min().values)})

# %%
s_a=pd.merge(s_a,rds[rds['funding_round_type']=='series-a'][['company_name','funded_at','raised_amount_usd']],how='left', on=['company_name','funded_at'])

# %%
s_a.columns =['company_name', 'sa_funded_at', 'sa_raised_amount_usd']

# %%
s_a=s_a.drop_duplicates()
s_a=s_a.dropna(subset=['sa_funded_at'])

# %%
len(s_a['company_name'].drop_duplicates())
# Out:
# 5808

# %%
df=pd.merge(comp2,s_a,how='left', on='company_name')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13543 entries, 0 to 13542
# Data columns (total 19 columns):
# permalink                13543 non-null object
# company_name             13543 non-null object
# homepage_url             12522 non-null object
# category_list            13128 non-null object
# funding_total_usd        13543 non-null object
# status                   13543 non-null object
# country_code             13018 non-null object
# state_code               12853 non-null object
# region                   12875 non-null object
# city                     12876 non-null object
# funding_rounds           13543 non-null int64
# founded_at               13543 non-null datetime64[ns]
# first_funding_at         13543 non-null datetime64[ns]
# last_funding_at          13543 non-null datetime64[ns]
# days_in_op               13543 non-null float64
# first_funding_dayinop    13543 non-null timedelta64[ns]
# last_funding_dayinop     13543 non-null timedelta64[ns]
# sa_funded_at             1863 non-null datetime64[ns]
# sa_raised_amount_usd     1754 non-null float64
# dtypes: datetime64[ns](4), float64(2), int64(1), object(10), timedelta64[ns](2)
# memory usage: 2.1+ MB

# %%
# df

# %%
df['sa_funded_daysop']=df['sa_funded_at']-df['founded_at']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13543 entries, 0 to 13542
# Data columns (total 20 columns):
# permalink                13543 non-null object
# company_name             13543 non-null object
# homepage_url             12522 non-null object
# category_list            13128 non-null object
# funding_total_usd        13543 non-null object
# status                   13543 non-null object
# country_code             13018 non-null object
# state_code               12853 non-null object
# region                   12875 non-null object
# city                     12876 non-null object
# funding_rounds           13543 non-null int64
# founded_at               13543 non-null datetime64[ns]
# first_funding_at         13543 non-null datetime64[ns]
# last_funding_at          13543 non-null datetime64[ns]
# days_in_op               13543 non-null float64
# first_funding_dayinop    13543 non-null timedelta64[ns]
# last_funding_dayinop     13543 non-null timedelta64[ns]
# sa_funded_at             1863 non-null datetime64[ns]
# sa_raised_amount_usd     1754 non-null float64
# sa_funded_daysop         1863 non-null timedelta64[ns]
# dtypes: datetime64[ns](4), float64(2), int64(1), object(10), timedelta64[ns](3)
# memory usage: 2.2+ MB

# %%
gp=rds[rds['funding_round_type']=='angel'].groupby('company_name')
angel=pd.DataFrame({'company_name':list(gp.groups.keys())})
angel['funded_at']=pd.DataFrame({'funded_at':list(gp['funded_at'].min().values)})
angel=pd.merge(angel,rds[rds['funding_round_type']=='angel'][['company_name','funded_at','raised_amount_usd']],how='left', on=['company_name','funded_at'])

# %%
angel.columns =['company_name', 'ag_funded_at', 'ag_raised_amount_usd']

# %%
gp=rds[rds['funding_round_type']=='venture'].groupby('company_name')
vent=pd.DataFrame({'company_name':list(gp.groups.keys())})
vent['funded_at']=pd.DataFrame({'funded_at':list(gp['funded_at'].min().values)})
vent=pd.merge(vent,rds[rds['funding_round_type']=='venture'][['company_name','funded_at','raised_amount_usd']],how='left', on=['company_name','funded_at'])

# %%
vent.columns=['company_name', 've_funded_at', 've_raised_amount_usd']

# %%
df=pd.merge(df,angel,how='left', on='company_name')

# %%
df=pd.merge(df,vent,how='left', on='company_name')

# %%
df=pd.merge(df,crowd,how='left', on='company_name')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13559 entries, 0 to 13558
# Data columns (total 26 columns):
# permalink                13559 non-null object
# company_name             13559 non-null object
# homepage_url             12537 non-null object
# category_list            13144 non-null object
# funding_total_usd        13559 non-null object
# status                   13559 non-null object
# country_code             13034 non-null object
# state_code               12869 non-null object
# region                   12891 non-null object
# city                     12892 non-null object
# funding_rounds           13559 non-null int64
# founded_at               13559 non-null datetime64[ns]
# first_funding_at         13559 non-null datetime64[ns]
# last_funding_at          13559 non-null datetime64[ns]
# days_in_op               13559 non-null float64
# first_funding_dayinop    13559 non-null timedelta64[ns]
# last_funding_dayinop     13559 non-null timedelta64[ns]
# sa_funded_at             1865 non-null datetime64[ns]
# sa_raised_amount_usd     1756 non-null float64
# sa_funded_daysop         1865 non-null timedelta64[ns]
# ag_funded_at             674 non-null datetime64[ns]
# ag_raised_amount_usd     539 non-null float64
# ve_funded_at             2475 non-null datetime64[ns]
# ve_raised_amount_usd     2259 non-null float64
# cr_funded_at             3 non-null datetime64[ns]
# cr_raised_amount_usd     3 non-null float64
# dtypes: datetime64[ns](7), float64(5), int64(1), object(10), timedelta64[ns](3)
# memory usage: 2.8+ MB

# %%
df['founded_at']=pd.to_datetime(df['founded_at'])

# %%
df['ve_funded_at']=pd.to_datetime(df['ve_funded_at'])

# %%
df['sa_funded_at']=pd.to_datetime(df['sa_funded_at'])

# %%
df['cr_funded_at']=pd.to_datetime(df['cr_funded_at'])# to be run

# %%
df['first_funding_at']=pd.to_datetime(df['first_funding_at'])

# %%
df['cr_funded_daysop']=df['cr_funded_at']-df['founded_at'] # to be run

# %%
df['cr_funded_daysop']=df['cr_funded_daysop'].astype('timedelta64[D]')

# %%
df['sa_funded_daysop']=df['sa_funded_at']-df['founded_at']

# %%
df['ag_funded_daysop']=df['ag_funded_at']-df['founded_at']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13559 entries, 0 to 13558
# Data columns (total 28 columns):
# permalink                13559 non-null object
# company_name             13559 non-null object
# homepage_url             12537 non-null object
# category_list            13144 non-null object
# funding_total_usd        13559 non-null object
# status                   13559 non-null object
# country_code             13034 non-null object
# state_code               12869 non-null object
# region                   12891 non-null object
# city                     12892 non-null object
# funding_rounds           13559 non-null int64
# founded_at               13559 non-null datetime64[ns]
# first_funding_at         13559 non-null datetime64[ns]
# last_funding_at          13559 non-null datetime64[ns]
# days_in_op               13559 non-null float64
# first_funding_dayinop    13559 non-null timedelta64[ns]
# last_funding_dayinop     13559 non-null timedelta64[ns]
# sa_funded_at             1865 non-null datetime64[ns]
# sa_raised_amount_usd     1756 non-null float64
# sa_funded_daysop         1865 non-null timedelta64[ns]
# ag_funded_at             674 non-null datetime64[ns]
# ag_raised_amount_usd     539 non-null float64
# ve_funded_at             2475 non-null datetime64[ns]
# ve_raised_amount_usd     2259 non-null float64
# cr_funded_at             3 non-null datetime64[ns]
# cr_raised_amount_usd     3 non-null float64
# cr_funded_daysop         3 non-null float64
# ag_funded_daysop         674 non-null timedelta64[ns]
# dtypes: datetime64[ns](7), float64(6), int64(1), object(10), timedelta64[ns](4)
# memory usage: 3.0+ MB

# %%
df['ve_funded_daysop']=df['ve_funded_at']-df['founded_at']

# %%
df['first_funding_dayinop']=df['first_funding_at']-df['founded_at']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13559 entries, 0 to 13558
# Data columns (total 29 columns):
# permalink                13559 non-null object
# company_name             13559 non-null object
# homepage_url             12537 non-null object
# category_list            13144 non-null object
# funding_total_usd        13559 non-null object
# status                   13559 non-null object
# country_code             13034 non-null object
# state_code               12869 non-null object
# region                   12891 non-null object
# city                     12892 non-null object
# funding_rounds           13559 non-null int64
# founded_at               13559 non-null datetime64[ns]
# first_funding_at         13559 non-null datetime64[ns]
# last_funding_at          13559 non-null datetime64[ns]
# days_in_op               13559 non-null float64
# first_funding_dayinop    13559 non-null timedelta64[ns]
# last_funding_dayinop     13559 non-null timedelta64[ns]
# sa_funded_at             1865 non-null datetime64[ns]
# sa_raised_amount_usd     1756 non-null float64
# sa_funded_daysop         1865 non-null timedelta64[ns]
# ag_funded_at             674 non-null datetime64[ns]
# ag_raised_amount_usd     539 non-null float64
# ve_funded_at             2475 non-null datetime64[ns]
# ve_raised_amount_usd     2259 non-null float64
# cr_funded_at             3 non-null datetime64[ns]
# cr_raised_amount_usd     3 non-null float64
# cr_funded_daysop         3 non-null float64
# ag_funded_daysop         674 non-null timedelta64[ns]
# ve_funded_daysop         2475 non-null timedelta64[ns]
# dtypes: datetime64[ns](7), float64(6), int64(1), object(10), timedelta64[ns](5)
# memory usage: 3.1+ MB

# %%
df['ag_funded_daysop']=df['ag_funded_daysop'].astype('timedelta64[D]')

# %%
df['ve_funded_daysop']=df['ve_funded_daysop'].astype('timedelta64[D]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13559 entries, 0 to 13558
# Data columns (total 29 columns):
# permalink                13559 non-null object
# company_name             13559 non-null object
# homepage_url             12537 non-null object
# category_list            13144 non-null object
# funding_total_usd        13559 non-null object
# status                   13559 non-null object
# country_code             13034 non-null object
# state_code               12869 non-null object
# region                   12891 non-null object
# city                     12892 non-null object
# funding_rounds           13559 non-null int64
# founded_at               13559 non-null datetime64[ns]
# first_funding_at         13559 non-null datetime64[ns]
# last_funding_at          13559 non-null datetime64[ns]
# days_in_op               13559 non-null float64
# first_funding_dayinop    13559 non-null timedelta64[ns]
# last_funding_dayinop     13559 non-null timedelta64[ns]
# sa_funded_at             1865 non-null datetime64[ns]
# sa_raised_amount_usd     1756 non-null float64
# sa_funded_daysop         1865 non-null timedelta64[ns]
# ag_funded_at             674 non-null datetime64[ns]
# ag_raised_amount_usd     539 non-null float64
# ve_funded_at             2475 non-null datetime64[ns]
# ve_raised_amount_usd     2259 non-null float64
# cr_funded_at             3 non-null datetime64[ns]
# cr_raised_amount_usd     3 non-null float64
# cr_funded_daysop         3 non-null float64
# ag_funded_daysop         674 non-null float64
# ve_funded_daysop         2475 non-null float64
# dtypes: datetime64[ns](7), float64(8), int64(1), object(10), timedelta64[ns](3)
# memory usage: 3.1+ MB

# %%
df['state_code'].value_counts()[:5]
# Out:
# CA    3095
# MA     788
# NY     643
# TX     532
# WA     312
# Name: state_code, dtype: int64

# %%
ind=df[df['state_code']=='CA'].index
df['CA']=0
df['CA'].iloc[ind]=1
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
ind=df[df['state_code']=='NY'].index
df['NY']=0
df['NY'].iloc[ind]=1

ind=df[df['state_code']=='MA'].index
df['MA']=0
df['MA'].iloc[ind]=1

ind=df[df['state_code']=='TX'].index
df['TX']=0
df['TX'].iloc[ind]=1

ind=df[df['state_code']=='WA'].index
df['WA']=0
df['WA'].iloc[ind]=1
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df['country_code'].value_counts()[:5]
# Out:
# USA    9248
# GBR     728
# CAN     437
# CHN     387
# FRA     293
# Name: country_code, dtype: int64

# %%
ind=df[df['country_code']=='USA'].index
df['USA']=0
df['USA'].iloc[ind]=1

ind=df[df['country_code']=='GRB'].index
df['GBR']=0
df['GBR'].iloc[ind]=1

ind=df[df['country_code']=='CAN'].index
df['CAN']=0
df['CAN'].iloc[ind]=1

ind=df[df['country_code']=='CHN'].index
df['CHN']=0
df['CHN'].iloc[ind]=1
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df['founded_year'] = df['founded_at'].dt.year
df['founded_month'] = df['founded_at'].dt.month

# %%
df=df.dropna(subset=['category_list', 'status','first_funding_dayinop', 'founded_at'])

# %%
df['sa_funded_daysop']=df['sa_funded_daysop'].astype('timedelta64[D]')

# %%
df['first_funding_dayinop']=df['first_funding_dayinop'].astype('timedelta64[D]')

# %%
inf=pd.read_csv('./data/inflation.csv')

# %%
df['founded_year']=df['founded_year'].astype(int)

# %%
inf['founded_year']=inf['YEAR']

# %%
df=pd.merge(df,inf[['founded_year', 'AVE']],how='left', on='founded_year')# AVE is the annual average inflation

# %%
cpi=pd.read_csv('./data/cpi.csv')

# %%
cpi['founded_year']=cpi['YEAR']

# %%
cpi[['founded_year','adj_base2018']].head()
# Out:
#    founded_year  adj_base2018
# 0        2018.0          1.00
# 1        2017.0          0.97
# 2        2016.0          0.95
# 3        2015.0          0.94
# 4        2014.0          0.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13144 entries, 0 to 13143
# Data columns (total 41 columns):
# permalink                13144 non-null object
# company_name             13144 non-null object
# homepage_url             12239 non-null object
# category_list            13144 non-null object
# funding_total_usd        13144 non-null object
# status                   13144 non-null object
# country_code             12692 non-null object
# state_code               12534 non-null object
# region                   12552 non-null object
# city                     12553 non-null object
# funding_rounds           13144 non-null int64
# founded_at               13144 non-null datetime64[ns]
# first_funding_at         13144 non-null datetime64[ns]
# last_funding_at          13144 non-null datetime64[ns]
# days_in_op               13144 non-null float64
# first_funding_dayinop    13144 non-null float64
# last_funding_dayinop     13144 non-null timedelta64[ns]
# sa_funded_at             1864 non-null datetime64[ns]
# sa_raised_amount_usd     1755 non-null float64
# sa_funded_daysop         1864 non-null float64
# ag_funded_at             672 non-null datetime64[ns]
# ag_raised_amount_usd     538 non-null float64
# ve_funded_at             2473 non-null datetime64[ns]
# ve_raised_amount_usd     2258 non-null float64
# cr_funded_at             3 non-null datetime64[ns]
# cr_raised_amount_usd     3 non-null float64
# cr_funded_daysop         3 non-null float64
# ag_funded_daysop         672 non-null float64
# ve_funded_daysop         2473 non-null float64
# CA                       13144 non-null int64
# NY                       13144 non-null int64
# MA                       13144 non-null int64
# TX                       13144 non-null int64
# WA                       13144 non-null int64
# USA                      13144 non-null int64
# GBR                      13144 non-null int64
# CAN                      13144 non-null int64
# CHN                      13144 non-null int64
# founded_year             13144 non-null int64
# founded_month            13144 non-null int64
# AVE                      13029 non-null float64
# dtypes: datetime64[ns](7), float64(11), int64(12), object(10), timedelta64[ns](1)
# memory usage: 4.2+ MB

# %%
df.columns
# Out:
# Index(['permalink', 'company_name', 'homepage_url', 'category_list',
#        'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'first_funding_at',
#        'last_funding_at', 'days_in_op', 'first_funding_dayinop',
#        'last_funding_dayinop', 'sa_funded_at', 'sa_raised_amount_usd',
#        'sa_funded_daysop', 'ag_funded_at', 'ag_raised_amount_usd',
#        've_funded_at', 've_raised_amount_usd', 'cr_funded_at',
#        'cr_raised_amount_usd', 'cr_funded_daysop', 'ag_funded_daysop',
#        've_funded_daysop', 'CA', 'NY', 'MA', 'TX', 'WA', 'USA ', 'GBR', 'CAN',
#        'CHN', 'founded_year', 'founded_month', 'AVE'],
#       dtype='object')

# %%
df.columns=['permalink', 'company_name', 'homepage_url', 'category_list',
       'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
       'city', 'funding_rounds', 'founded_at', 'first_funding_at',
       'last_funding_at', 'days_in_op', 'first_funding_dayinop',
       'last_funding_dayinop', 'sa_funded_at', 'sa_raised_amount_usd',
       'sa_funded_daysop', 'ag_funded_at', 'ag_raised_amount_usd',
       've_funded_at', 've_raised_amount_usd', 'cr_funded_at',
       'cr_raised_amount_usd', 'cr_funded_daysop', 'ag_funded_daysop',
       've_funded_daysop', 'CA', 'NY', 'MA', 'TX', 'WA', 'USA', 'GBR', 'CAN',
       'CHN', 'founded_year', 'founded_month', 'ave_inf_y']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-246-d41967d4d70a> in <module>()
#       8        'cr_raised_amount_usd', 'cr_funded_daysop', 'ag_funded_daysop',
#       9        've_funded_daysop', 'CA', 'NY', 'MA', 'TX', 'WA', 'USA', 'GBR', 'CAN',
# ---> 10        'CHN', 'founded_year', 'founded_month', 'ave_inf_y']
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    4383         try:
#    4384             object.__getattribute__(self, name)
# -> 4385             return object.__setattr__(self, name, value)
#    4386         except AttributeError:
#    4387             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     643
#     644     def _set_axis(self, axis, labels):
# --> 645         self._data.set_axis(axis, labels)
#     646         self._clear_item_cache()
#     647
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    3321             raise ValueError(
#    3322                 'Length mismatch: Expected axis has {old} elements, new '
# -> 3323                 'values have {new} elements'.format(old=old_len, new=new_len))
#    3324
#    3325         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 48 elements, new values have 41 elements

# %%
df=pd.merge(df,cpi[['founded_year','adj_base2018']],how='left', on='founded_year')# CPIt/CPI_2018, CPI consumer price index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13144 entries, 0 to 13143
# Data columns (total 42 columns):
# permalink                13144 non-null object
# company_name             13144 non-null object
# homepage_url             12239 non-null object
# category_list            13144 non-null object
# funding_total_usd        13144 non-null object
# status                   13144 non-null object
# country_code             12692 non-null object
# state_code               12534 non-null object
# region                   12552 non-null object
# city                     12553 non-null object
# funding_rounds           13144 non-null int64
# founded_at               13144 non-null datetime64[ns]
# first_funding_at         13144 non-null datetime64[ns]
# last_funding_at          13144 non-null datetime64[ns]
# days_in_op               13144 non-null float64
# first_funding_dayinop    13144 non-null float64
# last_funding_dayinop     13144 non-null timedelta64[ns]
# sa_funded_at             1864 non-null datetime64[ns]
# sa_raised_amount_usd     1755 non-null float64
# sa_funded_daysop         1864 non-null float64
# ag_funded_at             672 non-null datetime64[ns]
# ag_raised_amount_usd     538 non-null float64
# ve_funded_at             2473 non-null datetime64[ns]
# ve_raised_amount_usd     2258 non-null float64
# cr_funded_at             3 non-null datetime64[ns]
# cr_raised_amount_usd     3 non-null float64
# cr_funded_daysop         3 non-null float64
# ag_funded_daysop         672 non-null float64
# ve_funded_daysop         2473 non-null float64
# CA                       13144 non-null int64
# NY                       13144 non-null int64
# MA                       13144 non-null int64
# TX                       13144 non-null int64
# WA                       13144 non-null int64
# USA                      13144 non-null int64
# GBR                      13144 non-null int64
# CAN                      13144 non-null int64
# CHN                      13144 non-null int64
# founded_year             13144 non-null int64
# founded_month            13144 non-null int64
# ave_inf_y                13029 non-null float64
# adj_base2018             13029 non-null float64
# dtypes: datetime64[ns](7), float64(12), int64(12), object(10), timedelta64[ns](1)
# memory usage: 4.3+ MB

# %%
df['sa_raised_amount_usd_adj']=df['sa_raised_amount_usd']*df['adj_base2018']

# %%
df['ag_raised_amount_usd_adj']=df['ag_raised_amount_usd']*df['adj_base2018']

# %%
df['ve_raised_amount_usd_adj']=df['ve_raised_amount_usd']*df['adj_base2018']

# %%
df['cr_raised_amount_usd_adj']=df['cr_raised_amount_usd']*df['adj_base2018']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13144 entries, 0 to 13143
# Data columns (total 46 columns):
# permalink                   13144 non-null object
# company_name                13144 non-null object
# homepage_url                12239 non-null object
# category_list               13144 non-null object
# funding_total_usd           13144 non-null object
# status                      13144 non-null object
# country_code                12692 non-null object
# state_code                  12534 non-null object
# region                      12552 non-null object
# city                        12553 non-null object
# funding_rounds              13144 non-null int64
# founded_at                  13144 non-null datetime64[ns]
# first_funding_at            13144 non-null datetime64[ns]
# last_funding_at             13144 non-null datetime64[ns]
# days_in_op                  13144 non-null float64
# first_funding_dayinop       13144 non-null float64
# last_funding_dayinop        13144 non-null timedelta64[ns]
# sa_funded_at                1864 non-null datetime64[ns]
# sa_raised_amount_usd        1755 non-null float64
# sa_funded_daysop            1864 non-null float64
# ag_funded_at                672 non-null datetime64[ns]
# ag_raised_amount_usd        538 non-null float64
# ve_funded_at                2473 non-null datetime64[ns]
# ve_raised_amount_usd        2258 non-null float64
# cr_funded_at                3 non-null datetime64[ns]
# cr_raised_amount_usd        3 non-null float64
# cr_funded_daysop            3 non-null float64
# ag_funded_daysop            672 non-null float64
# ve_funded_daysop            2473 non-null float64
# CA                          13144 non-null int64
# NY                          13144 non-null int64
# MA                          13144 non-null int64
# TX                          13144 non-null int64
# WA                          13144 non-null int64
# USA                         13144 non-null int64
# GBR                         13144 non-null int64
# CAN                         13144 non-null int64
# CHN                         13144 non-null int64
# founded_year                13144 non-null int64
# founded_month               13144 non-null int64
# ave_inf_y                   13029 non-null float64
# adj_base2018                13029 non-null float64
# sa_raised_amount_usd_adj    1750 non-null float64
# ag_raised_amount_usd_adj    537 non-null float64
# ve_raised_amount_usd_adj    2253 non-null float64
# cr_raised_amount_usd_adj    3 non-null float64
# dtypes: datetime64[ns](7), float64(16), int64(12), object(10), timedelta64[ns](1)
# memory usage: 4.7+ MB

# %%
df=df.dropna(subset=['category_list', 'status','first_funding_dayinop', 'founded_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13144 entries, 0 to 13143
# Data columns (total 46 columns):
# permalink                   13144 non-null object
# company_name                13144 non-null object
# homepage_url                12239 non-null object
# category_list               13144 non-null object
# funding_total_usd           13144 non-null object
# status                      13144 non-null object
# country_code                12692 non-null object
# state_code                  12534 non-null object
# region                      12552 non-null object
# city                        12553 non-null object
# funding_rounds              13144 non-null int64
# founded_at                  13144 non-null datetime64[ns]
# first_funding_at            13144 non-null datetime64[ns]
# last_funding_at             13144 non-null datetime64[ns]
# days_in_op                  13144 non-null float64
# first_funding_dayinop       13144 non-null float64
# last_funding_dayinop        13144 non-null timedelta64[ns]
# sa_funded_at                1864 non-null datetime64[ns]
# sa_raised_amount_usd        1755 non-null float64
# sa_funded_daysop            1864 non-null float64
# ag_funded_at                672 non-null datetime64[ns]
# ag_raised_amount_usd        538 non-null float64
# ve_funded_at                2473 non-null datetime64[ns]
# ve_raised_amount_usd        2258 non-null float64
# cr_funded_at                3 non-null datetime64[ns]
# cr_raised_amount_usd        3 non-null float64
# cr_funded_daysop            3 non-null float64
# ag_funded_daysop            672 non-null float64
# ve_funded_daysop            2473 non-null float64
# CA                          13144 non-null int64
# NY                          13144 non-null int64
# MA                          13144 non-null int64
# TX                          13144 non-null int64
# WA                          13144 non-null int64
# USA                         13144 non-null int64
# GBR                         13144 non-null int64
# CAN                         13144 non-null int64
# CHN                         13144 non-null int64
# founded_year                13144 non-null int64
# founded_month               13144 non-null int64
# ave_inf_y                   13029 non-null float64
# adj_base2018                13029 non-null float64
# sa_raised_amount_usd_adj    1750 non-null float64
# ag_raised_amount_usd_adj    537 non-null float64
# ve_raised_amount_usd_adj    2253 non-null float64
# cr_raised_amount_usd_adj    3 non-null float64
# dtypes: datetime64[ns](7), float64(16), int64(12), object(10), timedelta64[ns](1)
# memory usage: 4.7+ MB

# %%
invs['investor_category_code'].unique()
# Out:
# array([nan, 'finance', 'web', 'nanotech', 'cleantech', 'biotech', 'other',
#        'consulting', 'education', 'nonprofit', 'hardware', 'games_video',
#        'software', 'advertising', 'security', 'public_relations',
#        'semiconductor', 'ecommerce', 'enterprise', 'mobile',
#        'network_hosting', 'social', 'news', 'legal', 'medical', 'search',
#        'health', 'government', 'pets', 'manufacturing', 'fashion',
#        'messaging', 'real_estate', 'transportation'], dtype=object)

# %%
ind=df[df['category_list'].str.contains('Biotech', case=False, na=False)].index
df['Biotech']=0
df['Biotech'].iloc[ind]=1
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
ind=df[df['category_list'].str.contains('web', case=False, na=False)].index
df['web']=0
df['web'].iloc[ind]=1
ind=df[df['category_list'].str.contains('nanotech', case=False, na=False)].index
df['nanotech']=0
df['nanotech'].iloc[ind]=1
ind=df[df['category_list'].str.contains('cleantech', case=False, na=False)].index
df['cleantech']=0
df['cleantech'].iloc[ind]=1
ind=df[df['category_list'].str.contains('consulting', case=False, na=False)].index
df['consulting']=0
df['consulting'].iloc[ind]=1
ind=df[df['category_list'].str.contains('education', case=False, na=False)].index
df['education']=0
df['education'].iloc[ind]=1
ind=df[df['category_list'].str.contains('hardware', case=False, na=False)].index
df['hardware']=0
df['hardware'].iloc[ind]=1
ind=df[df['category_list'].str.contains('games_video', case=False, na=False)].index
df['games_video']=0
df['games_video'].iloc[ind]=1
ind=df[df['category_list'].str.contains('software', case=False, na=False)].index
df['software']=0
df['software'].iloc[ind]=1
ind=df[df['category_list'].str.contains('advertising', case=False, na=False)].index
df['advertising']=0
df['advertising'].iloc[ind]=1
ind=df[df['category_list'].str.contains('security', case=False, na=False)].index
df['security']=0
df['security'].iloc[ind]=1
ind=df[df['category_list'].str.contains('public_relations', case=False, na=False)].index
df['public_relations']=0
df['public_relations'].iloc[ind]=1
ind=df[df['category_list'].str.contains( 'semiconductor', case=False, na=False)].index
df['semiconductor']=0
df['semiconductor'].iloc[ind]=1
ind=df[df['category_list'].str.contains( 'ecommerce', case=False, na=False)].index
df['ecommerce']=0
df['ecommerce'].iloc[ind]=1
ind=df[df['category_list'].str.contains('enterprise', case=False, na=False)].index
df['enterprise']=0
df['enterprise'].iloc[ind]=1
ind=df[df['category_list'].str.contains( 'mobile', case=False, na=False)].index
df['mobile']=0
df['mobile'].iloc[ind]=1
ind=df[df['category_list'].str.contains( 'network_hosting', case=False, na=False)].index
df['network_hosting']=0
df['network_hosting'].iloc[ind]=1
ind=df[df['category_list'].str.contains('social', case=False, na=False)].index
df['social']=0
df['social'].iloc[ind]=1
ind=df[df['category_list'].str.contains( 'news', case=False, na=False)].index
df['news']=0
df['news'].iloc[ind]=1
ind=df[df['category_list'].str.contains( 'legal', case=False, na=False)].index
df['legal']=0
df['legal'].iloc[ind]=1
ind=df[df['category_list'].str.contains('medical', case=False, na=False)].index
df['medical']=0
df['medical'].iloc[ind]=1
ind=df[df['category_list'].str.contains('search', case=False, na=False)].index
df['search']=0
df['search'].iloc[ind]=1
ind=df[df['category_list'].str.contains( 'health', case=False, na=False)].index
df['health']=0
df['health'].iloc[ind]=1
ind=df[df['category_list'].str.contains('government', case=False, na=False)].index
df['government']=0
df['government'].iloc[ind]=1
ind=df[df['category_list'].str.contains( 'pets', case=False, na=False)].index
df['pets']=0
df['pets'].iloc[ind]=1
ind=df[df['category_list'].str.contains( 'manufacturing', case=False, na=False)].index
df['manufacturing']=0
df['manufacturing'].iloc[ind]=1
ind=df[df['category_list'].str.contains( 'fashion', case=False, na=False)].index
df['fashion']=0
df['fashion'].iloc[ind]=1
ind=df[df['category_list'].str.contains('messaging', case=False, na=False)].index
df['messaging']=0
df['messaging'].iloc[ind]=1
ind=df[df['category_list'].str.contains('real_estate', case=False, na=False)].index
df['real_estate']=0
df['real_estate'].iloc[ind]=1
ind=df[df['category_list'].str.contains('transportation', case=False, na=False)].index
df['transportation']=0
df['transportation'].iloc[ind]=1
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df[df['web']==1]
# Out:
#                                                permalink  \
# 10                                    /organization/1bib
# 26                  /organization/2adpro-media-solutions
# 52                                   /organization/3leaf
# 80                                  /organization/58-com
# 89                       /organization/7signal-solutions
# 90                                  /organization/800app
# 91                          /organization/8020publishing
# 107                           /organization/a10-networks
# 122                                 /organization/abazab
# 130                               /organization/abebooks
# 139                            /organization/aboutus-org
# 179                       /organization/access-northeast
# 227                              /organization/acid-labs
# 228                                /organization/acinion
# 241                                /organization/acronis
# 248                       /organization/actelis-networks
# 273                         /organization/activestrategy
# 385                                 /organization/adviqo
# 398                           /organization/aep-networks
# 399                                 /organization/aepona
# 410                               /organization/aeropost
# 412                    /organization/aerosat-corporation
# 418                                   /organization/af83
# 436                      /organization/aftercad-software
# 465                         /organization/agily-networks
# 507                              /organization/airespace
# 514                       /organization/airspan-networks
# 533                         /organization/akonix-systems
# 538                                 /organization/aktino
# 545                                /organization/alatest
# ...                                                  ...
# 12888                               /organization/xoopit
# 12935                           /organization/yaolan-com
# 12956                              /organization/yesmail
# 12957                             /organization/yesvideo
# 12961  /organization/yippeeo-internet-marketing-solut...
# 12971                                /organization/yoics
# 12975                               /organization/yoonew
# 12984                              /organization/youcalc
# 12987                             /organization/youlicit
# 12990                        /organization/your-survival
# 12993                           /organization/yourstreet
# 12994                       /organization/yourtrumanshow
# 12996                                /organization/yovia
# 13004                               /organization/yuntaa
# 13021                                /organization/zanox
# 13025                               /organization/zappos
# 13027                        /organization/zave-networks
# 13038                               /organization/zebtab
# 13047                             /organization/zenfolio
# 13065                               /organization/zeturf
# 13066                       /organization/zeugma-systems
# 13069                              /organization/zhaopin
# 13076                              /organization/zigabid
# 13080                               /organization/zimbra
# 13082                               /organization/zingku
# 13102                                 /organization/zoji
# 13117                               /organization/zooomr
# 13127                              /organization/zubican
# 13132                               /organization/zumbox
# 13134                               /organization/zvents
#
#                                company_name                     homepage_url  \
# 10                                     1bib              http://www.1bib.com
# 26                   2AdPro Media Solutions            http://www.2adpro.com
# 52                                    3Leaf      http://www.3leafsystems.com
# 80                                   58.com                http://www.58.com
# 89                        7signal Solutions               http://7signal.com
# 90                                   800APP            http://www.800app.com
# 91                               8020 Media         http://www.8020media.com
# 107                            A10 Networks       http://www.a10networks.com
# 122                                  Abazab                              NaN
# 130                                AbeBooks          http://www.abebooks.com
# 139                             AboutUs.org           http://www.aboutus.org
# 179                        Access Northeast             http://www.axsne.com
# 227                               Acid Labs       http://www.acidlabsllc.com
# 228                               Blackwave          http://www.blackwave.tv
# 241                                 Acronis           http://www.acronis.com
# 248                        Actelis Networks           http://www.actelis.com
# 273                          ActiveStrategy    http://www.activestrategy.com
# 385                                  Adviqo            http://www.adviqo.com
# 398                            AEP Networks       http://www.aepnetworks.com
# 399                                  Aepona            http://www.aepona.com
# 410                                Aeropost              http://aeropost.com
# 412                     AeroSat Corporation           http://www.aerosat.com
# 418                                    AF83              http://www.af83.com
# 436                       Aftercad Software          http://www.aftercad.com
# 465                          Agily Networks             http://www.agily.com
# 507                               Airespace                              NaN
# 514                        Airspan Networks               http://airspan.com
# 533                          Akonix Systems            http://www.akonix.com
# 538                                  Aktino            http://www.aktino.com
# 545                                 alaTest               http://alatest.com
# ...                                     ...                              ...
# 12888                                Xoopit                http://xoopit.com
# 12935                            Yaolan.com            http://www.yaolan.com
# 12956                               Yesmail           http://www.yesmail.com
# 12957                              YesVideo          http://www.yesvideo.com
# 12961  YippeeO Internet Marketing Solutions  http://www.YippeeOMarketing.com
# 12971                                 Yoics                 http://yoics.com
# 12975                                yoonew            http://www.yoonew.com
# 12984                               youcalc           http://www.youcalc.com
# 12987                              Youlicit          http://www.youlicit.com
# 12990                         Your Survival      http://www.yoursurvival.com
# 12993                            YourStreet        http://www.yourstreet.com
# 12994                      Your Truman Show    http://www.yourtrumanshow.com
# 12996                                 Yovia             http://www.yovia.com
# 13004                                Yuntaa                http://yuntaa.com
# 13021                                 zanox             http://www.zanox.com
# 13025                                Zappos            http://www.zappos.com
# 13027                         Zave Networks          http://zavenetworks.com
# 13038                                Zebtab            http://www.zebtab.com
# 13047                         Zenfolio, Inc          http://www.zenfolio.com
# 13065                                ZEturf            http://www.zeturf.com
# 13066                        Zeugma Systems     http://www.zeugmasystems.com
# 13069                               Zhaopin           http://www.zhaopin.com
# 13076                               Zigabid           http://www.zigabid.com
# 13080                                Zimbra                http://zimbra.com
# 13082                                Zingku            http://www.zingku.com
# 13102                                  Zoji              http://www.zoji.com
# 13117                                Zooomr                http://zooomr.com
# 13127                               Zubican           http://www.zubican.com
# 13132                                Zumbox          https://www.zumbox.com/
# 13134                                Zvents            http://www.zvents.com
#
#                                            category_list funding_total_usd  \
# 10                                      Cars|Curated Web                 -
# 26     Ad Targeting|Advertising|Advertising Platforms...                 -
# 52                                           Web Hosting          65000000
# 80                         Curated Web|Internet|Software         876780000
# 89                                           Web Hosting           9850000
# 90                       Networking|Software|Web Hosting                 -
# 91               Curated Web|News|Photography|Publishing                 -
# 107    Cloud Computing|Communications Hardware|Hardwa...         118000000
# 122                                          Curated Web           4400000
# 130                                Curated Web|Textbooks                 -
# 139                                          Curated Web           7618249
# 179    Cloud Computing|Data Centers|Networking|Servic...           1999998
# 227               E-Commerce|Mobile|Software|Web Hosting                 -
# 228     Social Media|Storage|Video Streaming|Web Hosting          28000000
# 241    Flash Storage|Homeland Security|Storage|Web Ho...          11000000
# 248                        Internet|Software|Web Hosting         113616859
# 273                             Software|Web Development           2000000
# 385                                          Curated Web                 -
# 398                                          Web Hosting           5000000
# 399                                          Web Hosting          40000000
# 410                                          Curated Web           5000000
# 412                                          Web Hosting          45400000
# 418    Curated Web|Databases|Internet|Mobile|Software...                 -
# 436    3D|Architecture|CAD|Construction|Manufacturing...           1107000
# 465    Cloud Computing|Flash Storage|Networking|Peer-...            250000
# 507                                          Web Hosting          20000000
# 514                                   Mobile|Web Hosting         141636023
# 533                                          Curated Web          11000000
# 538                                          Web Hosting          30200000
# 545    Consumer Electronics|Hardware + Software|Opini...                 -
# ...                                                  ...               ...
# 12888  Curated Web|Email|Photo Sharing|Search|Social ...           6500000
# 12935                                        Curated Web          17700000
# 12956                                  Curated Web|Email           9000000
# 12957                                  Curated Web|Video          31361000
# 12961  Advertising|Email Marketing|Internet Marketing...           2000000
# 12971                             Networking|Web Hosting                 -
# 12975                                        Curated Web           4000000
# 12984  Analytics|Business Intelligence|Gadget|Graphic...           3840000
# 12987                                        Curated Web                 -
# 12990                                        Curated Web            425000
# 12993                                        Curated Web            250000
# 12994                        Advertising|Video|Web Tools           1300000
# 12996    Curated Web|Social Media|Social Media Marketing            300000
# 13004                                Storage|Web Hosting           1472100
# 13021                               Curated Web|Services                 -
# 13025                                        Curated Web          62750000
# 13027                                        Curated Web          15036298
# 13038  Content|Entertainment|Gadget|Games|Music|News|...            280000
# 13047                  Databases|Photography|Web Hosting            220000
# 13065                                        Curated Web          11373300
# 13066                                        Web Hosting          31500000
# 13069                               Curated Web|Internet         110000000
# 13076                        Concerts|Curated Web|Sports           1000000
# 13080  Collaboration|Email|Productivity Software|Soft...          14500000
# 13082                                        Curated Web           1000000
# 13102                                        Curated Web           1500000
# 13117               Curated Web|File Sharing|Photography             50000
# 13127     B2B|Curated Web|Internet Marketing|Procurement                 -
# 13132                               Curated Web|Internet          28300000
# 13134  Concerts|Curated Web|Entertainment|Events|Kids...          55200000
#
#           status country_code state_code                     region  \
# 10        closed          CHN         30                  Guangzhou
# 26     operating          USA         CA                Los Angeles
# 52      acquired          USA         CA                SF Bay Area
# 80           ipo          CHN         19                CHN - Other
# 89     operating          USA         OH             Akron - Canton
# 90     operating          CHN         22                    Beijing
# 91     operating          USA         CA                SF Bay Area
# 107          ipo          USA         CA                SF Bay Area
# 122       closed          USA         CA                SF Bay Area
# 130     acquired          CAN         BC                  Vancouver
# 139    operating          USA         OR           Portland, Oregon
# 179     acquired          USA         MA                     Boston
# 227    operating          USA         CA                Los Angeles
# 228     acquired          USA         MA                     Boston
# 241    operating          SGP        NaN                  Singapore
# 248    operating          USA         CA                SF Bay Area
# 273    operating          USA         PA               Philadelphia
# 385    operating          NaN        NaN                        NaN
# 398     acquired          USA         NJ                     Newark
# 399     acquired          GBR         R3                    Belfast
# 410    operating          USA         FL                      Miami
# 412    operating          USA         NH  Manchester, New Hampshire
# 418    operating          FRA         A8                      Paris
# 436    operating          CAN         BC                  Vancouver
# 465    operating          USA         CA                SF Bay Area
# 507     acquired          USA         CA                SF Bay Area
# 514          ipo          USA         FL               Palm Beaches
# 533    operating          USA         CA                  San Diego
# 538     acquired          USA         CA                    Anaheim
# 545    operating          SWE         26                  Stockholm
# ...          ...          ...        ...                        ...
# 12888   acquired          USA         CA                SF Bay Area
# 12935  operating          CHN         22                    Beijing
# 12956   acquired          USA         OR           Portland, Oregon
# 12957  operating          USA         CA                SF Bay Area
# 12961  operating          USA         VA                 VA - Other
# 12971  operating          USA         CA                SF Bay Area
# 12975     closed          USA         NY              New York City
# 12984   acquired          DNK         17                 Copenhagen
# 12987     closed          USA         NY              New York City
# 12990     closed          USA         CT                 CT - Other
# 12993  operating          USA         CA                SF Bay Area
# 12994  operating          USA         CA                SF Bay Area
# 12996  operating          USA         FL               Jacksonville
# 13004     closed          BEL         12                   Brussels
# 13021  operating          NaN        NaN                        NaN
# 13025   acquired          USA         NV                  Las Vegas
# 13027   acquired          USA         KS                Kansas City
# 13038     closed          GBR         H9                     London
# 13047   acquired          USA         CA                SF Bay Area
# 13065  operating          MLT        NaN                        NaN
# 13066     closed          CAN         ON                    Toronto
# 13069  operating          CHN         22                    Beijing
# 13076  operating          USA         CA                Los Angeles
# 13080   acquired          USA         CA                SF Bay Area
# 13082   acquired          USA         MA                     Boston
# 13102     closed          USA         WA                    Seattle
# 13117     closed          USA         CA                SF Bay Area
# 13127   acquired          USA         CA              Santa Barbara
# 13132     closed          USA         CA                Los Angeles
# 13134   acquired          USA         CA                SF Bay Area
#
#                        city ...   founded_year founded_month  ave_inf_y  \
# 10                Guangzhou ...           2006             1  19.363636
# 26           Woodland Hills ...           2006             9  19.363636
# 52              Santa Clara ...           2004             6  18.080808
# 80                 Chaoyang ...           2005             1  18.727273
# 89                    Akron ...           2006             1  19.363636
# 90                  Beijing ...           2004             5  18.080808
# 91            San Francisco ...           2006             6  19.363636
# 107                San Jose ...           2004            10  18.080808
# 122                Campbell ...           1997             1  15.212121
# 130                Victoria ...           1996             1  14.848485
# 139                Portland ...           2006             1  19.363636
# 179             Marlborough ...           1999             1  15.828283
# 227            Santa Monica ...           2003             1  17.581818
# 228                   Acton ...           2006             1  19.363636
# 241               Singapore ...           2002             1  17.169697
# 248                 Fremont ...           1998             1  15.464646
# 273        Plymouth Meeting ...           2000             1  16.393939
# 385                     NaN ...           2000             4  16.393939
# 398                Somerset ...           1998             1  15.464646
# 399                 Belfast ...           1999             1  15.828283
# 410                   Miami ...           1986             1  10.070707
# 412                 Amherst ...           1997             1  15.212121
# 418                   Paris ...           2006            11  19.363636
# 436               Vancouver ...           2004             5  18.080808
# 465                San Jose ...           2006            10  19.363636
# 507                San Jose ...           2001             7  16.888889
# 514              Boca Raton ...           1992             1  13.171717
# 533               San Diego ...           2000             1  16.393939
# 538                  Irvine ...           2003             1  17.581818
# 545               Stockholm ...           2005             1  18.727273
# ...                     ... ...            ...           ...        ...
# 12888         San Francisco ...           2004             1  18.080808
# 12935               Beijing ...           1999             1  15.828283
# 12956              Portland ...           1997             1  15.212121
# 12957           Santa Clara ...           1999             1  15.828283
# 12961          Purcellville ...           2006             6  19.363636
# 12971             Palo Alto ...           2006             1  19.363636
# 12975              New York ...           2004             1  18.080808
# 12984            Copenhagen ...           2006             6  19.363636
# 12987              New York ...           2006             9  19.363636
# 12990             Southport ...           2006            10  19.363636
# 12993         San Francisco ...           2006            11  19.363636
# 12994         San Francisco ...           2006            11  19.363636
# 12996        Atlantic Beach ...           2006            10  19.363636
# 13004      Groot-bijgaarden ...           2006             8  19.363636
# 13021                   NaN ...           2000             3  16.393939
# 13025             Las Vegas ...           1999             1  15.828283
# 13027           Kansas City ...           2006             1  19.363636
# 13038                London ...           2005             8  18.727273
# 13047            Menlo Park ...           2005             1  18.727273
# 13065                   NaN ...           2001             1  16.888889
# 13066         Richmond Hill ...           2004             1  18.080808
# 13069               Beijing ...           1997             1  15.212121
# 13076  La Canada Flintridge ...           2006            12  19.363636
# 13080             Palo Alto ...           2003             1  17.581818
# 13082               Waltham ...           2005             1  18.727273
# 13102               Seattle ...           2004            10  18.080808
# 13117         San Francisco ...           2006             3  19.363636
# 13127              Moorpark ...           2006            12  19.363636
# 13132           Los Angeles ...           2006            10  19.363636
# 13134             San Mateo ...           2005             3  18.727273
#
#       adj_base2018  sa_raised_amount_usd_adj  ag_raised_amount_usd_adj  \
# 10            0.80                       NaN                       NaN
# 26            0.80                       NaN                       NaN
# 52            0.75                       NaN                       NaN
# 80            0.78                       NaN                       NaN
# 89            0.80                       NaN                  200000.0
# 90            0.75                       NaN                       NaN
# 91            0.80                       NaN                       NaN
# 107           0.75                 4500000.0                       NaN
# 122           0.64                       NaN                       NaN
# 130           0.62                       NaN                       NaN
# 139           0.80                 2000000.0                       NaN
# 179           0.66                       NaN                       NaN
# 227           0.73                       NaN                       NaN
# 228           0.80                 4000000.0                       NaN
# 241           0.71                       NaN                       NaN
# 248           0.65                       NaN                       NaN
# 273           0.68                       NaN                       NaN
# 385           0.68                       NaN                       NaN
# 398           0.65                       NaN                       NaN
# 399           0.66                       NaN                       NaN
# 410           0.43                       NaN                       NaN
# 412           0.64                       NaN                       NaN
# 418           0.80                       NaN                       NaN
# 436           0.75                       NaN                       NaN
# 465           0.80                       NaN                  200000.0
# 507           0.70                       NaN                       NaN
# 514           0.56                 5600000.0                       NaN
# 533           0.68                       NaN                       NaN
# 538           0.73                       NaN                       NaN
# 545           0.78                       NaN                       NaN
# ...            ...                       ...                       ...
# 12888         0.75                 1125000.0                       NaN
# 12935         0.66                       NaN                       NaN
# 12956         0.64                       NaN                       NaN
# 12957         0.66                  874500.0                       NaN
# 12961         0.80                 1600000.0                       NaN
# 12971         0.80                       NaN                       NaN
# 12975         0.75                 1500000.0                       NaN
# 12984         0.80                       NaN                       NaN
# 12987         0.80                       NaN                       NaN
# 12990         0.80                       NaN                  340000.0
# 12993         0.80                       NaN                  200000.0
# 12994         0.80                       NaN                 1040000.0
# 12996         0.80                       NaN                  240000.0
# 13004         0.80                       NaN                       NaN
# 13021         0.68                       NaN                       NaN
# 13025         0.66                   99000.0                       NaN
# 13027         0.80                       NaN                       NaN
# 13038         0.78                       NaN                       NaN
# 13047         0.78                       NaN                       NaN
# 13065         0.70                       NaN                       NaN
# 13066         0.75                       NaN                       NaN
# 13069         0.64                       NaN                       NaN
# 13076         0.80                       NaN                  400000.0
# 13080         0.73                       NaN                       NaN
# 13082         0.78                       NaN                       NaN
# 13102         0.75                 1125000.0                       NaN
# 13117         0.80                       NaN                   40000.0
# 13127         0.80                       NaN                       NaN
# 13132         0.80                 2000000.0                       NaN
# 13134         0.78                 5460000.0                  156000.0
#
#       ve_raised_amount_usd_adj cr_raised_amount_usd_adj  Biotechnology  web
# 10                         NaN                      NaN              0    1
# 26                         NaN                      NaN              0    1
# 52                         NaN                      NaN              0    1
# 80                         NaN                      NaN              0    1
# 89                         NaN                      NaN              0    1
# 90                         NaN                      NaN              0    1
# 91                         NaN                      NaN              0    1
# 107                        NaN                      NaN              0    1
# 122                 2624000.00                      NaN              0    1
# 130                        NaN                      NaN              0    1
# 139                        NaN                      NaN              0    1
# 179                 1319998.68                      NaN              0    1
# 227                        NaN                      NaN              0    1
# 228                        NaN                      NaN              0    1
# 241                 7810000.00                      NaN              0    1
# 248                 3055000.00                      NaN              0    1
# 273                        NaN                      NaN              0    1
# 385                        NaN                      NaN              0    1
# 398                        NaN                      NaN              0    1
# 399                        NaN                      NaN              0    1
# 410                        NaN                      NaN              0    1
# 412                19584000.00                      NaN              0    1
# 418                        NaN                      NaN              0    1
# 436                        NaN                      NaN              0    1
# 465                        NaN                      NaN              0    1
# 507                        NaN                      NaN              0    1
# 514                        NaN                      NaN              0    1
# 533                        NaN                      NaN              0    1
# 538                        NaN                      NaN              0    1
# 545                        NaN                      NaN              0    1
# ...                        ...                      ...            ...  ...
# 12888                      NaN                      NaN              0    1
# 12935                      NaN                      NaN              0    1
# 12956                      NaN                      NaN              0    1
# 12957               3062400.00                      NaN              0    1
# 12961                      NaN                      NaN              0    1
# 12971                      NaN                      NaN              0    1
# 12975                      NaN                      NaN              0    1
# 12984                      NaN                      NaN              0    1
# 12987                      NaN                      NaN              0    1
# 12990                      NaN                      NaN              0    1
# 12993                      NaN                      NaN              0    1
# 12994                      NaN                      NaN              0    1
# 12996                      NaN                      NaN              0    1
# 13004                      NaN                      NaN              0    1
# 13021                      NaN                      NaN              0    1
# 13025                      NaN                      NaN              0    1
# 13027                      NaN                      NaN              0    1
# 13038                      NaN                      NaN              0    1
# 13047                      NaN                      NaN              0    1
# 13065                      NaN                      NaN              0    1
# 13066                      NaN                      NaN              0    1
# 13069                      NaN                      NaN              0    1
# 13076                      NaN                      NaN              0    1
# 13080                      NaN                      NaN              0    1
# 13082                      NaN                      NaN              0    1
# 13102                      NaN                      NaN              0    1
# 13117                      NaN                      NaN              0    1
# 13127                      NaN                      NaN              0    1
# 13132               7760000.00                      NaN              0    1
# 13134                      NaN                      NaN              0    1
#
# [979 rows x 48 columns]

# %%
ind=df[df['category_list'].str.contains('finance', case=False, na=False)].index
df['finance']=0
df['finance'].iloc[ind]=1

# %%
df.columns
# Out:
# Index(['permalink', 'company_name', 'homepage_url', 'category_list',
#        'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'first_funding_at',
#        'last_funding_at', 'days_in_op', 'first_funding_dayinop',
#        'last_funding_dayinop', 'sa_funded_at', 'sa_raised_amount_usd',
#        'sa_funded_daysop', 'ag_funded_at', 'ag_raised_amount_usd',
#        've_funded_at', 've_raised_amount_usd', 'cr_funded_at',
#        'cr_raised_amount_usd', 'cr_funded_daysop', 'ag_funded_daysop',
#        've_funded_daysop', 'CA', 'NY', 'MA', 'TX', 'WA', 'USA ', 'GBR', 'CAN',
#        'CHN', 'founded_year', 'founded_month', 'ave_inf_y', 'adj_base2018',
#        'sa_raised_amount_usd_adj', 'ag_raised_amount_usd_adj',
#        've_raised_amount_usd_adj', 'cr_raised_amount_usd_adj', 'Biotechnology',
#        'web', 'Biotech', 'nanotech', 'cleantech', 'consulting', 'education',
#        'hardware', 'games_video', 'software', 'advertising', 'security',
#        'public_relations', 'semiconductor', 'ecommerce', 'enterprise',
#        'mobile', 'network_hosting', 'social', 'news', 'legal', 'medical',
#        'search', 'health', 'government', 'pets', 'manufacturing', 'fashion',
#        'messaging', 'real_estate', 'transportation'],
#       dtype='object')

# %%
df[['web', 'Biotech', 'nanotech', 'cleantech', 'consulting', 'education',
       'hardware', 'games_video', 'software', 'advertising', 'security',
       'public_relations', 'semiconductor', 'ecommerce', 'enterprise',
       'mobile', 'network_hosting', 'social', 'news', 'legal', 'medical',
       'search', 'health', 'government', 'pets', 'manufacturing', 'fashion',
       'messaging', 'real_estate', 'transportation']].sum().sort_values(ascending=False)[:20].index
# Out:
# Index(['software', 'Biotech', 'health', 'web', 'mobile', 'enterprise',
#        'hardware', 'advertising', 'security', 'manufacturing', 'social',
#        'semiconductor', 'medical', 'consulting', 'education', 'search',
#        'messaging', 'news', 'transportation', 'fashion'],
#       dtype='object')

# %%
df_model=df[['company_name', 'status', 'country_code', 'state_code', 'days_in_op', 'first_funding_dayinop',
       'sa_funded_daysop', 'cr_funded_daysop', 'ag_funded_daysop',
       've_funded_daysop', 'CA', 'NY', 'MA', 'TX', 'WA','founded_month', 'ave_inf_y',
       'sa_raised_amount_usd_adj', 'ag_raised_amount_usd_adj',
       've_raised_amount_usd_adj', 'cr_raised_amount_usd_adj', 
        'software', 'Biotech', 'health', 'web', 'mobile', 'enterprise',
       'hardware', 'advertising', 'security', 'manufacturing', 'social',
       'semiconductor', 'medical', 'consulting', 'education', 'search',
       'messaging', 'news', 'transportation', 'fashion']]

# %%
df_model=df_model[df_model['country_code']=='USA'].drop_duplicates()

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9005 entries, 1 to 13142
# Data columns (total 41 columns):
# company_name                9005 non-null object
# status                      9005 non-null object
# country_code                9005 non-null object
# state_code                  9002 non-null object
# days_in_op                  9005 non-null float64
# first_funding_dayinop       9005 non-null float64
# sa_funded_daysop            1821 non-null float64
# cr_funded_daysop            3 non-null float64
# ag_funded_daysop            652 non-null float64
# ve_funded_daysop            2421 non-null float64
# CA                          9005 non-null int64
# NY                          9005 non-null int64
# MA                          9005 non-null int64
# TX                          9005 non-null int64
# WA                          9005 non-null int64
# founded_month               9005 non-null int64
# ave_inf_y                   8912 non-null float64
# sa_raised_amount_usd_adj    1709 non-null float64
# ag_raised_amount_usd_adj    522 non-null float64
# ve_raised_amount_usd_adj    2209 non-null float64
# cr_raised_amount_usd_adj    3 non-null float64
# software                    9005 non-null int64
# Biotech                     9005 non-null int64
# health                      9005 non-null int64
# web                         9005 non-null int64
# mobile                      9005 non-null int64
# enterprise                  9005 non-null int64
# hardware                    9005 non-null int64
# advertising                 9005 non-null int64
# security                    9005 non-null int64
# manufacturing               9005 non-null int64
# social                      9005 non-null int64
# semiconductor               9005 non-null int64
# medical                     9005 non-null int64
# consulting                  9005 non-null int64
# education                   9005 non-null int64
# search                      9005 non-null int64
# messaging                   9005 non-null int64
# news                        9005 non-null int64
# transportation              9005 non-null int64
# fashion                     9005 non-null int64
# dtypes: float64(11), int64(26), object(4)
# memory usage: 2.9+ MB

# %%
df_model=df_model.fillna(0)

# %%
df_model.to_csv('./data/start-up_mod.csv')

# %%
y=df['sa_funded_daysop']
plt.hist(y, range=(y.min(), y.max()));
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
y.describe()
# Out:
# count     1864.000000
# mean      1879.836910
# std       3278.330935
# min      -1208.000000
# 25%        448.750000
# 50%       1037.000000
# 75%       2486.500000
# max      61421.000000
# Name: sa_funded_daysop, dtype: float64

# %%
df_model2=df[['company_name', 'status', 'first_funding_dayinop', 'cr_funded_daysop', 'ag_funded_daysop',
       've_funded_daysop', 'CA', 'NY', 'MA', 'TX', 'WA','founded_month', 'ave_inf_y', 'ag_raised_amount_usd_adj',
       've_raised_amount_usd_adj', 'cr_raised_amount_usd_adj', 
        'software', 'Biotech', 'health', 'web', 'mobile', 'enterprise',
       'hardware', 'advertising', 'security', 'manufacturing', 'social',
       'semiconductor', 'medical', 'consulting', 'education', 'search',
       'messaging', 'news', 'transportation', 'fashion']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-304-d2eb78dc4ffd> in <module>()
#       2 df_model2=df[['company_name','status','category_code', 'CA', 'NY','MA', 'TX', 'WA', 'founded_month', 'first_funding_dayinop',
#       3         'ave_inf_y', 'ag_funded_daysop', 'ag_raised_amount_usd_adj', 'cr_funded_daysop', 'cr_raised_amount_usd_adj',
# ----> 4         'sa_funded_daysop','sa_raised_amount_usd_adj']]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['category_code'] not in index"

# %%
df_model2=df_model2.fillna(0)

# %%
df_model2=df_model2[df_model2['sa_funded_daysop']>=0]

# %%
# removing funding that occured hafter 10 years of operation
df_model2=df_model2.reset_index()

# %%
ind=df_model2[df_model2['sa_funded_daysop']>(9*365)].index

# %%
df_model2['sa_funded_daysop'].iloc[ind]=0
df_model2['sa_raised_amount_usd_adj'].iloc[ind]=0

# %%
df_model2.info()

# %%
y=df_model2['sa_funded_daysop']
plt.hist(y, range=(y.min(), y.max()));

# %%
y.max()

# %%
df_model2.to_csv('./data/start-up_mod_w_sa.csv')

# %%
# !ls /Users/carolina/start-up-classification/data

# %%
df.columns
# Out:
# Index(['permalink', 'company_name', 'homepage_url', 'category_list',
#        'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'first_funding_at',
#        'last_funding_at', 'days_in_op', 'first_funding_dayinop',
#        'last_funding_dayinop', 'sa_funded_at', 'sa_raised_amount_usd',
#        'sa_funded_daysop', 'ag_funded_at', 'ag_raised_amount_usd',
#        've_funded_at', 've_raised_amount_usd', 'cr_funded_at',
#        'cr_raised_amount_usd', 'cr_funded_daysop', 'ag_funded_daysop',
#        've_funded_daysop', 'CA', 'NY', 'MA', 'TX', 'WA', 'USA ', 'GBR', 'CAN',
#        'CHN', 'founded_year', 'founded_month', 'ave_inf_y', 'adj_base2018',
#        'sa_raised_amount_usd_adj', 'ag_raised_amount_usd_adj',
#        've_raised_amount_usd_adj', 'cr_raised_amount_usd_adj', 'Biotechnology',
#        'web', 'Biotech', 'nanotech', 'cleantech', 'consulting', 'education',
#        'hardware', 'games_video', 'software', 'advertising', 'security',
#        'public_relations', 'semiconductor', 'ecommerce', 'enterprise',
#        'mobile', 'network_hosting', 'social', 'news', 'legal', 'medical',
#        'search', 'health', 'government', 'pets', 'manufacturing', 'fashion',
#        'messaging', 'real_estate', 'transportation', 'USA'],
#       dtype='object')

# %%
df2=df[['company_name','founded_at','country_code','status', 'CA', 'NY','MA', 'TX', 'WA', 'founded_month', 'first_funding_dayinop',
        'ave_inf_y', 'ag_funded_daysop', 'ag_raised_amount_usd_adj','web', 'Biotech', 'nanotech', 'cleantech', 'consulting', 'education',
       'hardware', 'games_video', 'software', 'advertising', 'security',
       'public_relations', 'semiconductor', 'ecommerce', 'enterprise',
       'mobile', 'network_hosting', 'social', 'news', 'legal', 'medical',
       'search', 'health', 'government', 'pets', 'manufacturing', 'fashion',
       'messaging', 'real_estate', 'transportation']]

# %%
df2=df2[df2['country_code']=='USA']

# %%
adq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18966 entries, 0 to 18967
# Data columns (total 18 columns):
# company_permalink         18966 non-null object
# company_name              18966 non-null object
# company_category_list     13985 non-null object
# company_country_code      14300 non-null object
# company_state_code        14020 non-null object
# company_region            14058 non-null object
# company_city              14058 non-null object
# acquirer_permalink        18966 non-null object
# acquirer_name             18966 non-null object
# acquirer_category_list    16578 non-null object
# acquirer_country_code     17796 non-null object
# acquirer_state_code       17531 non-null object
# acquirer_region           17607 non-null object
# acquirer_city             17607 non-null object
# acquired_at               18954 non-null datetime64[ns]
# acquired_month            18954 non-null object
# price_amount              5011 non-null float64
# price_currency_code       18960 non-null object
# dtypes: datetime64[ns](1), float64(1), object(16)
# memory usage: 2.7+ MB

# %%
ind=adq[adq['acquired_at']=='3201-10-21'].index
adq=adq.drop(index=ind)

# %%
ind=adq[adq['acquired_at']=='1201-11-03 00:00:00'].index
adq=adq.drop(index=ind)

# %%
adq['acquired_at']=pd.to_datetime(adq['acquired_at'])

# %%
df2=df2.drop_duplicates()

# %%
df2=pd.merge(df2,adq[['company_name','acquired_at']],how='left',on='company_name')

# %%
df2['adq_daysonop']=df2['acquired_at']-df2['founded_at']

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9084 entries, 0 to 9083
# Data columns (total 46 columns):
# company_name                9084 non-null object
# founded_at                  9084 non-null datetime64[ns]
# country_code                9084 non-null object
# status                      9084 non-null object
# CA                          9084 non-null int64
# NY                          9084 non-null int64
# MA                          9084 non-null int64
# TX                          9084 non-null int64
# WA                          9084 non-null int64
# founded_month               9084 non-null int64
# first_funding_dayinop       9084 non-null float64
# ave_inf_y                   8990 non-null float64
# ag_funded_daysop            658 non-null float64
# ag_raised_amount_usd_adj    523 non-null float64
# web                         9084 non-null int64
# Biotech                     9084 non-null int64
# nanotech                    9084 non-null int64
# cleantech                   9084 non-null int64
# consulting                  9084 non-null int64
# education                   9084 non-null int64
# hardware                    9084 non-null int64
# games_video                 9084 non-null int64
# software                    9084 non-null int64
# advertising                 9084 non-null int64
# security                    9084 non-null int64
# public_relations            9084 non-null int64
# semiconductor               9084 non-null int64
# ecommerce                   9084 non-null int64
# enterprise                  9084 non-null int64
# mobile                      9084 non-null int64
# network_hosting             9084 non-null int64
# social                      9084 non-null int64
# news                        9084 non-null int64
# legal                       9084 non-null int64
# medical                     9084 non-null int64
# search                      9084 non-null int64
# health                      9084 non-null int64
# government                  9084 non-null int64
# pets                        9084 non-null int64
# manufacturing               9084 non-null int64
# fashion                     9084 non-null int64
# messaging                   9084 non-null int64
# real_estate                 9084 non-null int64
# transportation              9084 non-null int64
# acquired_at                 2059 non-null datetime64[ns]
# adq_daysonop                2059 non-null timedelta64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(36), object(3), timedelta64[ns](1)
# memory usage: 3.3+ MB

# %%
y=df2[df2['status']=='acquired']['adq_daysonop']/timedelta(days=1)

# %%
y.describe()
# Out:
# count     2016.000000
# mean      4238.712798
# std       3820.280916
# min       -430.000000
# 25%       2498.000000
# 50%       3561.000000
# 75%       5026.000000
# max      62783.000000
# Name: adq_daysonop, dtype: float64

# %%
plt.hist(y, range=(y.min(), y.max()));
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
5026.000000/365
# Out:
# 13.76986301369863

# %%
y=df2[df2['status']=='acquired']['adq_daysonop']/timedelta(days=1)
x=df2[df2['status']=='acquired']['category_code']

# %%
plt.figure(figsize= [10,10])
plt.scatter(y,x)

# %%
x.describe()

# %%
soft=df2[df2['category_code']=='software']

# %%
# percentace of software companies that are adquired
len(soft[soft['status']=='acquired'])/len(soft)

# %%
#percentage of web companies that are adquired
len(df2[df2['category_code']=='web'][df2['status']=='acquired'])/len(df2[df2['category_code']=='web'])

# %%
test=pd.get_dummies(df2[['category_code']])

# %%
# top 10 categories by number of companies
test.sum().sort_values(ascending=False)[:10]

# %%
# top 10 categories by number of companies acquired
pd.get_dummies(df2[df2['status']=='acquired']['category_code']).sum().sort_values(ascending=False)[:10]

# %%
# top 20 categories by percentage of companies acquired
(pd.get_dummies(df2[df2['status']=='acquired']['category_code']).sum()/pd.get_dummies(df2['category_code']).sum()).sort_values(ascending=False)[:20]

# %%
# top 10 categories by number of companies ipo
pd.get_dummies(df2[df2['status']=='ipo']['category_code']).sum().sort_values(ascending=False)[:10]

# %%
# top 20 categories by percentage of companies ipo
(pd.get_dummies(df2[df2['status']=='ipo']['category_code']).sum()/pd.get_dummies(df2['category_code']).sum()).sort_values(ascending=False)[:20]

# %%
df2[(df2['category_code']=='music') & (df2['status']=='ipo')]

# %%
df2[(df2['category_code']=='biotech') & (df2['status']=='ipo')]

# %%
df2[(df2['category_code']=='software') & (df2['status']=='ipo')]

# %%
df2[(df2['category_code']=='web') & (df2['status']=='ipo')]

# %%
comp.columns=['permalink', 'company_name', 'category_code', 'funding_total_usd', 'status',
       'country_code', 'state_code', 'region', 'city', 'funding_rounds',
       'founded_at', 'founded_month', 'founded_quarter', 'founded_year',
       'first_funding_at', 'last_funding_at', 'last_milestone_at',
       'days_in_op']

# %%
df3=pd.merge(comp,adq[['company_name','acquired_at']],how='left',on='company_name')

# %%
df3.info()

# %%
df3['adq_daysonop']=df3['acquired_at']-df3['founded_at']

# %%
df3['adq_daysonop']=df3['adq_daysonop'].astype('timedelta64[D]')

# %%
df3=df3[df3['adq_daysonop']>0]

# %%
df3=df3.dropna(subset=['category_code', 'status','founded_at'])

# %%
len(df3[df3['status']=='acquired'])

# %%
y=df3[df3['status']=='acquired']['adq_daysonop']
x=df3[df3['status']=='acquired']['category_code']

# %%
plt.figure(figsize= [11,11])
plt.hist(y, range=(y.min(), y.max()),edgecolor='black', color='royalblue')
plt.title("Company time in opeartion at acquisition", size = 25)
plt.xlabel('days', size = 20, labelpad = 15)
plt.xticks(size=15)
plt.yticks(size=15)
sns.despine();

# %%
y.describe()

# %%
plt.figure(figsize= [11,11])
plt.scatter(y,x)
plt.title("Time to adquisition by company category", size = 25)
plt.xlabel('Time in operation at acquisition, days', size = 20, labelpad = 15)
plt.ylabel('Category code              ', size = 20, rotation = 0, labelpad = 35)
plt.xticks(size=14)
plt.yticks(size=14)
ax = plt.gca()
ax.yaxis.set_label_coords(-0.06,0.97)
sns.despine();

# %%
3234/365

# %%
len(comp[comp['status']=='acquired'])/len(comp)

# %%
len(comp)

# %%
comp['founded_year'].describe()

# %%
y=comp['founded_year']
plt.figure(figsize= [11,11])
plt.hist(y, range=(y.min(), y.max()),edgecolor='black', color='royalblue')
