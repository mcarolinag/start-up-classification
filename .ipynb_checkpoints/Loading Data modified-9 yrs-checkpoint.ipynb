# %%
import requests
import time
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import os

# %%
from sqlalchemy import create_engine, inspect

# %%
from datetime import timedelta

# %%
from patsy import dmatrices

from sklearn import linear_model as lm
from sklearn.linear_model import LogisticRegression
from sklearn import cross_validation
from sklearn import metrics
from sklearn.metrics import confusion_matrix
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.metrics import roc_curve, auc

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn import pipeline, preprocessing

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn import naive_bayes
from sklearn.metrics import accuracy_score, classification_report

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
adq=pd.read_csv('./data/crunchbase-acquisitions.csv',encoding = "ISO-8859-1")

# %%
adq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6185 entries, 0 to 6184
# Data columns (total 20 columns):
# company_permalink         4651 non-null object
# company_name              4651 non-null object
# company_category_code     3933 non-null object
# company_country_code      4651 non-null object
# company_state_code        4543 non-null object
# company_region            4651 non-null object
# company_city              4532 non-null object
# acquirer_permalink        4651 non-null object
# acquirer_name             4651 non-null object
# acquirer_category_code    4137 non-null object
# acquirer_country_code     4384 non-null object
# acquirer_state_code       3877 non-null object
# acquirer_region           4651 non-null object
# acquirer_city             4262 non-null object
# acquired_at               4651 non-null object
# acquired_month            4651 non-null object
# acquired_quarter          4651 non-null object
# acquired_year             4651 non-null float64
# price_amount              1409 non-null float64
# price_currency_code       4648 non-null object
# dtypes: float64(2), object(18)
# memory usage: 966.5+ KB

# %%
comp=pd.read_csv('./data/crunchbase-companies.csv',encoding = "ISO-8859-1")

# %%
comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17727 entries, 0 to 17726
# Data columns (total 17 columns):
# permalink            17727 non-null object
# name                 17727 non-null object
# category_code        17328 non-null object
# funding_total_usd    16222 non-null object
# status               17727 non-null object
# country_code         17727 non-null object
# state_code           17480 non-null object
# region               17727 non-null object
# city                 17462 non-null object
# funding_rounds       17727 non-null int64
# founded_at           13676 non-null object
# founded_month        13676 non-null object
# founded_quarter      13676 non-null object
# founded_year         13676 non-null float64
# first_funding_at     17622 non-null object
# last_funding_at      17622 non-null object
# last_milestone_at    10528 non-null object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 2.3+ MB

# %%
comp2=comp

# %%
comp2['founded_at']=pd.to_datetime(comp2['founded_at'])

# %%
comp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17727 entries, 0 to 17726
# Data columns (total 17 columns):
# permalink            17727 non-null object
# name                 17727 non-null object
# category_code        17328 non-null object
# funding_total_usd    16222 non-null object
# status               17727 non-null object
# country_code         17727 non-null object
# state_code           17480 non-null object
# region               17727 non-null object
# city                 17462 non-null object
# funding_rounds       17727 non-null int64
# founded_at           13676 non-null datetime64[ns]
# founded_month        13676 non-null object
# founded_quarter      13676 non-null object
# founded_year         13676 non-null float64
# first_funding_at     17622 non-null object
# last_funding_at      17622 non-null object
# last_milestone_at    10528 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(14)
# memory usage: 2.3+ MB

# %%
#date for database snapshot
reft='2013-10-01 00:00:00'

# %%
reft=pd.Series({'reft':reft})

# %%
reft=pd.to_datetime(reft)

# %%
reft[0]
# Out:
# Timestamp('2013-10-01 00:00:00')

# %%
comp2['founded_at'][0]
# Out:
# Timestamp('2012-06-01 00:00:00')

# %%
comp2['days_in_op']=reft[0]-comp2['founded_at']

# %%
comp2[['days_in_op','founded_at']]
# Out:
#       days_in_op founded_at
# 0       487 days 2012-06-01
# 1       639 days 2012-01-01
# 2       722 days 2011-10-10
# 3            NaT        NaT
# 4     10135 days 1986-01-01
# 5      4656 days 2001-01-01
# 6      1188 days 2010-07-01
# 7            NaT        NaT
# 8       746 days 2011-09-16
# 9      5022 days 2000-01-01
# 10     1644 days 2009-04-01
# 11      639 days 2012-01-01
# 12     1369 days 2010-01-01
# 13           NaT        NaT
# 14      725 days 2011-10-07
# 15      639 days 2012-01-01
# 16     2465 days 2007-01-01
# 17     1359 days 2010-01-11
# 18     1369 days 2010-01-01
# 19      884 days 2011-05-01
# 20     1600 days 2009-05-15
# 21     8674 days 1990-01-01
# 22     2679 days 2006-06-01
# 23     1919 days 2008-06-30
# 24           NaT        NaT
# 25      731 days 2011-10-01
# 26     4656 days 2001-01-01
# 27      670 days 2011-12-01
# 28     2100 days 2008-01-01
# 29      426 days 2012-08-01
# ...          ...        ...
# 17697   670 days 2011-12-01
# 17698        NaT        NaT
# 17699  1461 days 2009-10-01
# 17700   581 days 2012-02-28
# 17701  4656 days 2001-01-01
# 17702  2557 days 2006-10-01
# 17703  2625 days 2006-07-25
# 17704  2345 days 2007-05-01
# 17705  2406 days 2007-03-01
# 17706   639 days 2012-01-01
# 17707  2465 days 2007-01-01
# 17708        NaT        NaT
# 17709        NaT        NaT
# 17710  1369 days 2010-01-01
# 17711  1635 days 2009-04-10
# 17712  3136 days 2005-03-01
# 17713  1734 days 2009-01-01
# 17714  1004 days 2011-01-01
# 17715        NaT        NaT
# 17716        NaT        NaT
# 17717  2531 days 2006-10-27
# 17718  3561 days 2004-01-01
# 17719  2830 days 2006-01-01
# 17720  2284 days 2007-07-01
# 17721  2100 days 2008-01-01
# 17722        NaT        NaT
# 17723  1004 days 2011-01-01
# 17724        NaT        NaT
# 17725  5387 days 1999-01-01
# 17726   273 days 2013-01-01
#
# [17727 rows x 2 columns]

# %%
comp2['days_in_op'][0]
# Out:
# Timedelta('487 days 00:00:00')

# %%
10*365
# Out:
# 3650

# %%
comp2= comp2[(comp2['days_in_op']>'3650 days 00:00:00')]

# %%
comp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3186 entries, 4 to 17725
# Data columns (total 18 columns):
# permalink            3186 non-null object
# name                 3186 non-null object
# category_code        3094 non-null object
# funding_total_usd    3012 non-null object
# status               3186 non-null object
# country_code         3186 non-null object
# state_code           3148 non-null object
# region               3186 non-null object
# city                 3160 non-null object
# funding_rounds       3186 non-null int64
# founded_at           3186 non-null datetime64[ns]
# founded_month        3186 non-null object
# founded_quarter      3186 non-null object
# founded_year         3186 non-null float64
# first_funding_at     3172 non-null object
# last_funding_at      3172 non-null object
# last_milestone_at    1928 non-null object
# days_in_op           3186 non-null timedelta64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(14), timedelta64[ns](1)
# memory usage: 472.9+ KB

# %%
comp2['first_funding_at']=pd.to_datetime(comp2['first_funding_at'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
comp2['last_funding_at']=pd.to_datetime(comp2['last_funding_at'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
comp2['first_funding_dayinop']=comp2['first_funding_at']-comp2['founded_at']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
comp2['last_funding_dayinop']=comp2['last_funding_at']-comp2['founded_at']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
comp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3186 entries, 4 to 17725
# Data columns (total 20 columns):
# permalink                3186 non-null object
# name                     3186 non-null object
# category_code            3094 non-null object
# funding_total_usd        3012 non-null object
# status                   3186 non-null object
# country_code             3186 non-null object
# state_code               3148 non-null object
# region                   3186 non-null object
# city                     3160 non-null object
# funding_rounds           3186 non-null int64
# founded_at               3186 non-null datetime64[ns]
# founded_month            3186 non-null object
# founded_quarter          3186 non-null object
# founded_year             3186 non-null float64
# first_funding_at         3172 non-null datetime64[ns]
# last_funding_at          3172 non-null datetime64[ns]
# last_milestone_at        1928 non-null object
# days_in_op               3186 non-null timedelta64[ns]
# first_funding_dayinop    3172 non-null timedelta64[ns]
# last_funding_dayinop     3172 non-null timedelta64[ns]
# dtypes: datetime64[ns](3), float64(1), int64(1), object(12), timedelta64[ns](3)
# memory usage: 522.7+ KB

# %%
ind=comp2[comp2['first_funding_dayinop'].isnull()].index

# %%
comp2
# Out:
#                                          permalink  \
# 4                           /company/1-800-dentist
# 5                             /company/10-20-media
# 9                                /company/1010data
# 21                            /company/170-systems
# 26                                /company/1stdibs
# 31                     /company/22nd-century-group
# 41                 /company/2nd-story-software-inc
# 50                              /company/37signals
# 57                             /company/3d-systems
# 59          /company/3dcart-shopping-cart-software
# 63                               /company/3guppies
# 70     /company/3tier-environmental-forecast-group
# 71                           /company/3vr-security
# 108                               /company/8x8-inc
# 121                           /company/a123systems
# 122                    /company/aaipharma-services
# 125                   /company/aastrom-biosciences
# 126                           /company/abacast-inc
# 128                                /company/abazab
# 135                       /company/ability-network
# 139                            /company/abizinabox
# 147                    /company/above-all-software
# 157                       /company/acacia-research
# 163                                /company/accela
# 167                        /company/accelerated-io
# 173                             /company/accelitec
# 174                             /company/accellion
# 179                       /company/accept-software
# 180                                /company/accera
# 182                      /company/access-360-media
# ...                                            ...
# 17493                               /company/zadby
# 17502                             /company/zalicus
# 17507                               /company/zango
# 17510                                 /company/zap
# 17514                              /company/zappos
# 17526                              /company/zazzle
# 17529                             /company/zeachem
# 17532                       /company/zebra-imaging
# 17543                   /company/zend-technologies
# 17550                             /company/zenimax
# 17552                    /company/zeno-corporation
# 17556                            /company/zenprise
# 17564                             /company/zeomega
# 17566                   /company/zephyr-technology
# 17587                           /company/zettacore
# 17591                      /company/zevez-payments
# 17606                         /company/zilker-labs
# 17608                            /company/zilliant
# 17612                              /company/zimbra
# 17627                              /company/zipcar
# 17640                           /company/ziptronix
# 17652                   /company/zolo-technologies
# 17654              /company/zonare-medical-systems
# 17656                                /company/zong
# 17663                /company/zoom-media-marketing
# 17668                            /company/zoominfo
# 17669                            /company/zoomingo
# 17672                         /company/zoomsystems
# 17701                       /company/zumba-fitness
# 17725                                   /company/x
#
#                                          name     category_code  \
# 4                               1-800-DENTIST            health
# 5                                 10-20 Media         ecommerce
# 9                                    1010data          software
# 21                                170 Systems          software
# 26                                    1stdibs         ecommerce
# 31                         22nd Century Group           biotech
# 41                   2nd Story Software, Inc.          software
# 50                                  37signals  public_relations
# 57                                 3D Systems          software
# 59              3dCart Shopping Cart Software         ecommerce
# 63                                   3Guppies       games_video
# 70                                      3TIER         cleantech
# 71                                        3VR          security
# 108                                   8x8 Inc   network_hosting
# 121                              A123 Systems          nanotech
# 122                        AAIPharma Services           biotech
# 125                       Aastrom Biosciences           biotech
# 126                                   Abacast         analytics
# 128                                    Abazab               NaN
# 135                           ABILITY Network           medical
# 139                                aBIZinaBOX        consulting
# 147                        Above All Software     semiconductor
# 157                           Acacia Research             other
# 163                                    Accela          software
# 167                            Accelerated IO          software
# 173                                 Accelitec          software
# 174                                 Accellion        enterprise
# 179                           Accept Software          software
# 180                                    Accera           biotech
# 182                          Access 360 Media       advertising
# ...                                       ...               ...
# 17493                                   Zadby       games_video
# 17502                                 Zalicus           biotech
# 17507                                   Zango       games_video
# 17510                                     ZAP        automotive
# 17514                                  Zappos               web
# 17526                                  Zazzle         ecommerce
# 17529                                 ZeaChem         cleantech
# 17532                           Zebra Imaging       games_video
# 17543                       Zend Technologies          software
# 17550                                 ZeniMax       games_video
# 17552                        Zeno Corporation            health
# 17556                                Zenprise            mobile
# 17564                                 ZeOmega           biotech
# 17566                       Zephyr Technology           biotech
# 17587                               ZettaCore     semiconductor
# 17591                       Zevez Corporation          software
# 17606                             Zilker Labs     semiconductor
# 17608                                Zilliant          software
# 17612                                  Zimbra        enterprise
# 17627                                  Zipcar    transportation
# 17640                               Ziptronix     semiconductor
# 17652                       Zolo Technologies          hardware
# 17654                  Zonare Medical Systems           biotech
# 17656                                    Zong            mobile
# 17663  Zoom Media & Marketing - United States       advertising
# 17668                                ZoomInfo            search
# 17669                                Zoomingo         ecommerce
# 17672                             ZoomSystems          hardware
# 17701                           Zumba Fitness            health
# 17725                                   [x+1]        enterprise
#
#       funding_total_usd     status country_code state_code           region  \
# 4                   NaN  operating          USA         CA      Los Angeles
# 5                750000  operating          USA         MD    Washington DC
# 9              35000000  operating          USA         NY         New York
# 21             14000000   acquired          USA         MA           Boston
# 26             42000000  operating          USA         NY         New York
# 31              4951950        ipo          USA         NY         Clarence
# 41             85000000   acquired          USA         IA     Cedar Rapids
# 50                  NaN  operating          USA         IL          Chicago
# 57              4144131        ipo          USA         SC        Rock Hill
# 59              1250000  operating          USA         FL  Fort Lauderdale
# 63             20000000  operating          USA         WA          Seattle
# 70             15000000  operating          USA         WA          Seattle
# 71             53000000  operating          USA         CA           SF Bay
# 108            30608728   acquired          USA         CA           SF Bay
# 121           502860000        ipo          USA         MA           Boston
# 122            20000000  operating          USA         NC       Wilmington
# 125            40000000  operating          USA         MI          Detroit
# 126              500000  operating          USA         WA        Vancouver
# 128             4100000  operating          USA         CA           SF Bay
# 135            27000000  operating          USA         MN      Minneapolis
# 139              500000  operating          USA         IL          Chicago
# 147             2100000  operating          USA         CA           SF Bay
# 157           244600000        ipo          USA         CA      Los Angeles
# 163            35000000  operating          USA         CA           SF Bay
# 167             3255325  operating          USA         OK            Tulsa
# 173             1100000  operating          USA         WA       Bellingham
# 174            13410901  operating          USA         CA           SF Bay
# 179            25305000   acquired          USA         CA           SF Bay
# 180           130631610  operating          USA         CO           Denver
# 182            20000000  operating          USA         CA      Los Angeles
# ...                 ...        ...          ...        ...              ...

# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
invs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52870 entries, 0 to 52869
# Data columns (total 20 columns):
# company_permalink         52869 non-null object
# company_name              52869 non-null object
# company_category_code     52227 non-null object
# company_country_code      52869 non-null object
# company_state_code        52378 non-null object
# company_region            52869 non-null object
# company_city              52337 non-null object
# investor_permalink        52868 non-null object
# investor_name             52868 non-null object
# investor_category_code    2443 non-null object
# investor_country_code     40869 non-null object
# investor_state_code       36061 non-null object
# investor_region           52868 non-null object
# investor_city             40390 non-null object
# funding_round_type        52867 non-null object
# funded_at                 52867 non-null object
# funded_month              52867 non-null object
# funded_quarter            52867 non-null object
# funded_year               52867 non-null float64
# raised_amount_usd         49271 non-null float64
# dtypes: float64(2), object(18)
# memory usage: 8.1+ MB

# %%
rds=pd.read_csv('./data/crunchbase-rounds.csv',encoding = "ISO-8859-1")

# %%
rds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31679 entries, 0 to 31678
# Data columns (total 13 columns):
# company_permalink        31679 non-null object
# company_name             31679 non-null object
# company_category_code    31215 non-null object
# company_country_code     31679 non-null object
# company_state_code       31334 non-null object
# company_region           31679 non-null object
# company_city             31329 non-null object
# funding_round_type       31679 non-null object
# funded_at                31679 non-null object
# funded_month             31679 non-null object
# funded_quarter           31679 non-null object
# funded_year              31679 non-null int64
# raised_amount_usd        29100 non-null float64
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.1+ MB

# %%
rds['funded_at']=pd.to_datetime(rds['funded_at'])

# %%
comp.shape
# Out:
# (17727, 18)

# %%
invs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52870 entries, 0 to 52869
# Data columns (total 20 columns):
# company_permalink         52869 non-null object
# company_name              52869 non-null object
# company_category_code     52227 non-null object
# company_country_code      52869 non-null object
# company_state_code        52378 non-null object
# company_region            52869 non-null object
# company_city              52337 non-null object
# investor_permalink        52868 non-null object
# investor_name             52868 non-null object
# investor_category_code    2443 non-null object
# investor_country_code     40869 non-null object
# investor_state_code       36061 non-null object
# investor_region           52868 non-null object
# investor_city             40390 non-null object
# funding_round_type        52867 non-null object
# funded_at                 52867 non-null object
# funded_month              52867 non-null object
# funded_quarter            52867 non-null object
# funded_year               52867 non-null float64
# raised_amount_usd         49271 non-null float64
# dtypes: float64(2), object(18)
# memory usage: 8.1+ MB

# %%
invs
# Out:
#                               company_permalink  \
# 0                             /company/advercar
# 1                           /company/launchgram
# 2                                 /company/utap
# 3                             /company/zoopshop
# 4                             /company/efuneral
# 5                                /company/tackk
# 6                             /company/acclaimd
# 7                             /company/acclaimd
# 8                             /company/toviefor
# 9                             /company/ohk-labs
# 10                              /company/lovely
# 11                        /company/peertransfer
# 12                            /company/spotdock
# 13                              /company/fisker
# 14                              /company/fisker
# 15                      /company/metroflats-com
# 16                            /company/mesocoat
# 17                           /company/trilliant
# 18                        /company/power-assure
# 19                           /company/trilliant
# 20                           /company/ecotality
# 21                              /company/evalve
# 22                              /company/ovalis
# 23              /company/alvine-pharmaceuticals
# 24                    /company/avaxia-biologics
# 25              /company/aurasense-therapeutics
# 26                        /company/librarything
# 27                           /company/heliovolt
# 28     /company/airband-communications-holdings
# 29                                /company/xand
# ...                                         ...
# 52840                           /company/meddik
# 52841                       /company/blue-apron
# 52842                           /company/chatid
# 52843          /company/breakthrough-behavioral
# 52844                            /company/plaid
# 52845                         /company/pokitdok
# 52846                        /company/fitocracy
# 52847                           /company/square
# 52848                          /company/mixrank
# 52849                        /company/socialcam
# 52850                           /company/nuzzel
# 52851                        /company/thirdlove
# 52852                            /company/mxd3d
# 52853                            /company/mxd3d
# 52854                          /company/verious
# 52855                   /company/identified-com
# 52856                      /company/haulerdeals
# 52857                    /company/when-you-wish
# 52858                         /company/farmeron
# 52859              /company/theraclone-sciences
# 52860                        /company/simplegeo
# 52861                          /company/open-me
# 52862               /company/comprehend-systems
# 52863                         /company/payoneer
# 52864                         /company/outbrain
# 52865                    /company/garantia-data
# 52866                      /company/duda-mobile
# 52867                       /company/sitebrains
# 52868               /company/comprehend-systems
# 52869                      /company/smartthings
#
#                           company_name company_category_code  \
# 0                             AdverCar           advertising
# 1                           LaunchGram                  news
# 2                                 uTaP             messaging
# 3                             ZoopShop              software
# 4                             eFuneral                   web
# 5                                Tackk                   web
# 6                             Acclaimd             analytics
# 7                             Acclaimd             analytics
# 8                             ToVieFor             ecommerce
# 9                             OHK Labs                sports
# 10                              Lovely           real_estate
# 11                        peerTransfer               finance
# 12                            spotdock                   web
# 13                   Fisker Automotive            automotive
# 14                   Fisker Automotive            automotive
# 15                      MetroFlats.com                travel
# 16                            MesoCoat              nanotech
# 17                           Trilliant              hardware
# 18                        Power Assure       network_hosting
# 19                           Trilliant              hardware
# 20                           ECOtality             cleantech
# 21                              Evalve               biotech
# 22                              Ovalis               biotech
# 23              Alvine Pharmaceuticals               biotech
# 24                    Avaxia Biologics               biotech
# 25              AuraSense Therapeutics               biotech
# 26                        LibraryThing                   web
# 27                           HelioVolt             cleantech
# 28     Airband Communications Holdings                mobile
# 29                                Xand              software
# ...                                ...                   ...
# 52840                           Meddik                health
# 52841                       Blue Apron           hospitality
# 52842                           ChatID                mobile
# 52843          Breakthrough Behavioral                health
# 52844                            Plaid              software
# 52845                         PokitDok                mobile
# 52846                        Fitocracy                   web
# 52847                           Square                mobile
# 52848                          MixRank           advertising
# 52849                        Socialcam                mobile
# 52850                           Nuzzel                  news
# 52851                        ThirdLove             ecommerce
# 52852                            MXD3D                   web
# 52853                            MXD3D                   web
# 52854                          Verious                mobile
# 52855                       Identified             analytics
# 52856                      HaulerDeals               fashion
# 52857                    When You Wish             nonprofit
# 52858                         Farmeron             analytics
# 52859              Theraclone Sciences               biotech
# 52860                        SimpleGeo           advertising
# 52861                          Open Me             ecommerce
# 52862               Comprehend Systems            enterprise
# 52863                         Payoneer                 other
# 52864                         Outbrain                   web
# 52865                    Garantia Data            enterprise
# 52866                       DudaMobile                mobile
# 52867                       SiteBrains              software
# 52868               Comprehend Systems            enterprise
# 52869                      SmartThings                mobile
#
#       company_country_code company_state_code         company_region  \
# 0                      USA                 CA                 SF Bay
# 1                      USA                 CA                 SF Bay
# 2                      USA                NaN  United States - Other
# 3                      USA                 OH               Columbus
# 4                      USA                 OH              Cleveland
# 5                      USA                 OH              Cleveland
# 6                      USA                 OH               Columbus
# 7                      USA                 OH               Columbus
# 8                      USA                 NY               New York
# 9                      USA                 FL             Palm Beach
# 10                     USA                 CA                 SF Bay
# 11                     USA                 MA                 Boston
# 12                     USA                 NY               New York
# 13                     USA                 CA            Los Angeles
# 14                     USA                 CA            Los Angeles
# 15                     USA                 NJ            Cedar Grove
# 16                     USA                 OH              Cleveland
# 17                     USA                 CA                 SF Bay
# 18                     USA                 CA                 SF Bay
# 19                     USA                 CA                 SF Bay
# 20                     USA                 CA                 SF Bay
# 21                     USA                 CA                 SF Bay
# 22                     USA                 CA                 SF Bay
# 23                     USA                 CA                 SF Bay
# 24                     USA                 MA                 Boston
# 25                     USA                 IL                Chicago
# 26                     USA                 ME               Portland
# 27                     USA                 TX                 Austin
# 28                     USA                 TX                 Dallas
# 29                     USA                 NY               New York
# ...                    ...                ...                    ...
# 52840                  USA                 NY               New York
# 52841                  USA                 NY               New York
# 52842                  USA                 NY               New York
# 52843                  USA                 CA                 SF Bay
# 52844                  USA                 CA                 SF Bay
# 52845                  USA                 CA                 SF Bay
# 52846                  USA                 NY               New York
# 52847                  USA                 CA                 SF Bay
# 52848                  USA                 CA                 SF Bay
# 52849                  USA                 CA     Santa Clara County
# 52850                  USA                 CA                 SF Bay
# 52862           Palo Alto                                  /person/zod-nazem
# 52863            New York                                /person/zohar-gilon
# 52864       New York City                                /person/zohar-gilon
# 52865         Santa Clara                                /person/zohar-gilon
# 52866           Palo Alto                                /person/zohar-gilon
# 52867       San Francisco                               /person/zohar-israel
# 52868           Palo Alto                            /person/zorba-lieberman
# 52869         Minneapolis                               /person/zorik-gordon
#
#                                   investor_name investor_category_code  \
# 0                             1-800-FLOWERS.COM                    NaN
# 1                                   10Xelerator                finance
# 2                                   10Xelerator                finance
# 3                                   10Xelerator                finance
# 4                                   10Xelerator                finance
# 5                                   10Xelerator                finance
# 6                                   10Xelerator                finance
# 7                                   10Xelerator                finance
# 8      2010 NYU Stern Business Plan Competition                    NaN
# 9                               22Hundred Group                    NaN
# 10                                        3taps                    web
# 11                                     500 Hats                    NaN
# 12                                 9mmedia, LLC                    NaN
# 13                                 A123 Systems               nanotech
# 14                                 A123 Systems               nanotech
# 15                               AA Investments                    NaN
# 16                                       Abakan              cleantech
# 17                                          ABB              cleantech
# 18                                          ABB              cleantech
# 19                                          ABB              cleantech
# 20                                          ABB              cleantech
# 21                                  Abbott Labs                biotech
# 22                                  Abbott Labs                biotech
# 23                                       AbbVie                biotech
# 24                                       AbbVie                biotech
# 25                                       AbbVie                biotech
# 26                                     AbeBooks                    web
# 27                                Abengoa Solar              cleantech
# 28                                ABRY Partners                  other
# 29                                ABRY Partners                  other
# ...                                         ...                    ...
# 52840                             Zach Weinberg                    NaN
# 52841                             Zach Weinberg                    NaN
# 52842                             Zach Weinberg                    NaN
# 52843                             Zach Weinberg                    NaN
# 52844                             Zach Weinberg                    NaN
# 52845                              Zach Zeitlin                    NaN
# 52846                            Zachary Aarons                    NaN
# 52847                             Zachary Bogue                    NaN
# 52848                             Zachary Bogue                    NaN
# 52849                             Zachary Bogue                    NaN
# 52850                             Zachary Bogue                    NaN
# 52851                             Zachary Bogue                    NaN
# 52852                                Zaid Ayoub                    NaN
# 52853                                Zaid Ayoub                    NaN
# 52854                                 Zain Khan                    NaN
# 52855                                  Zao Yang                    NaN
# 52856                                  Zaw Thet                    NaN
# 52857                              Zelda Marzec                    NaN
# 52858                            Zeljko Mataija                    NaN
# 52859                             Zenyaku Kogyo                    NaN
# 52860                                Ziv Navoth                    NaN
# 52861                                Ziver Birg                    NaN
# 52862                                 Zod Nazem                    NaN
# 52863                               Zohar Gilon                    NaN
# 52864                               Zohar Gilon                    NaN
# 52865                               Zohar Gilon                    NaN
# 52866                               Zohar Gilon                    NaN
# 52867                              zohar israel                    NaN
# 52868                           Zorba Lieberman                    NaN
# 52869                              Zorik Gordon                    NaN
#
#       investor_country_code investor_state_code  investor_region  \
# 0                       USA                  NY         New York
# 1                       USA                  OH         Columbus
# 2                       USA                  OH         Columbus
# 3                       USA                  OH         Columbus
# 4                       USA                  OH         Columbus
# 5                       USA                  OH         Columbus
# 6                       USA                  OH         Columbus
# 7                       USA                  OH         Columbus
# 8                       NaN                 NaN          unknown
# 9                       NaN                 NaN          unknown
# 10                      USA                  CA           SF Bay
# 11                      USA                  CA           SF Bay
# 12                      NaN                 NaN          unknown
# 13                      USA                  MA           Boston
# 14                      USA                  MA           Boston
# 15                      BMU                 NaN  Bermuda - Other
# 16                      USA                  FL            Miami
# 17                      CHE                 NaN           Zurich
# 18                      CHE                 NaN           Zurich
# 19                      CHE                 NaN           Zurich
# 20                      CHE                 NaN           Zurich
# 21                      USA                  IL          Chicago
# 22                      USA                  IL          Chicago
# 23                      USA                  IL          Chicago
# 24                      USA                  IL          Chicago
# 25                      USA                  IL          Chicago
# 26                      CAN                 NaN         Victoria
# 27                      ESP                 NaN          Sevilla
# 28                      USA                  MA           Boston
# 29                      USA                  MA           Boston
# ...                     ...                 ...              ...
# 52840                   NaN                 NaN          unknown
# 52841                   NaN                 NaN          unknown
# 52842                   NaN                 NaN          unknown
# 52843                   NaN                 NaN          unknown
# 52844                   NaN                 NaN          unknown
# 52845                   NaN                 NaN          unknown
# 52846                   NaN                 NaN          unknown
# 52847                   NaN                 NaN          unknown
# 52848                   NaN                 NaN          unknown
# 52849                   NaN                 NaN          unknown
# 52850                   NaN                 NaN          unknown
# 52851                   NaN                 NaN          unknown
# 52852                   NaN                 NaN          unknown
# 52853                   NaN                 NaN          unknown
# 52854                   NaN                 NaN          unknown
# 52855                   NaN                 NaN          unknown
# 52856                   NaN                 NaN          unknown
# 52857                   NaN                 NaN          unknown
# 52858                   NaN                 NaN          unknown
# 52859                   NaN                 NaN          unknown
# 52860                   NaN                 NaN          unknown
# 52861                   NaN                 NaN          unknown
# 52862                   NaN                 NaN          unknown
# 52863                   NaN                 NaN          unknown
# 52864                   NaN                 NaN          unknown
# 52865                   NaN                 NaN          unknown
# 52866                   NaN                 NaN          unknown
# 52867                   NaN                 NaN          unknown
# 52868                   NaN                 NaN          unknown
# 52869                   NaN                 NaN          unknown
#
#        investor_city funding_round_type   funded_at funded_month  \
# 0           New York           series-a  2012-10-30      2012-10
# 1           Columbus              other  2012-01-23      2012-01
# 2           Columbus              other  2012-01-01      2012-01
# 3           Columbus              angel  2012-02-15      2012-02
# 4           Columbus              other  2011-09-08      2011-09
# 5           Columbus              other  2012-02-01      2012-02
# 6           Columbus              angel  2012-06-01      2012-06
# 7           Columbus              angel  2012-08-07      2012-08
# 8                NaN              angel  2010-04-01      2010-04
# 9                NaN              angel  2011-09-01      2011-09
# 10     San Francisco           series-a  2012-10-01      2012-10
# 11         Palo Alto              angel  2010-10-28      2010-10
# 12               NaN              angel  2012-01-10      2012-01
# 13         Watertown           series-a  2010-05-01      2010-05
# 14         Watertown            venture  2011-02-22      2011-02
# 15               NaN              angel  2010-08-18      2010-08
# 16             Miami            venture  2009-12-14      2009-12
# 17            Zurich           series-b  2010-07-15      2010-07
# 18            Zurich            venture  2010-09-20      2010-09
# 19            Zurich            venture  2010-12-21      2010-12
# 20            Zurich            venture  2011-01-09      2011-01
# 21       Des Plaines          series-c+  2007-11-27      2007-11
# 22       Des Plaines           series-b  2007-01-30      2007-01
# 26           2006-Q2       2006.0                NaN
# 27           2007-Q4       2007.0        101000000.0
# 28           2011-Q3       2011.0         20000000.0
# 29           2013-Q3       2013.0        200000000.0
# ...              ...          ...                ...
# 52840        2012-Q2       2012.0           750000.0
# 52841        2013-Q1       2013.0          3000000.0
# 52842        2012-Q1       2012.0                NaN
# 52843        2012-Q3       2012.0           900000.0
# 52844        2013-Q3       2013.0          2800000.0
# 52845        2012-Q3       2012.0          1300000.0
# 52846        2011-Q3       2011.0           250000.0
# 52847        2009-Q4       2009.0         10000000.0
# 52848        2011-Q4       2011.0          1500000.0
# 52849        2012-Q2       2012.0                NaN
# 52850        2012-Q4       2012.0          1700000.0
# 52851        2012-Q4       2012.0          5600000.0
# 52852        2012-Q1       2012.0           300000.0
# 52853        2011-Q1       2011.0           300000.0
# 52854        2011-Q2       2011.0           800000.0
# 52855        2012-Q2       2012.0         21000000.0
# 52856        2012-Q4       2012.0          1250000.0
# 52857        2011-Q1       2011.0          1500000.0
# 52858        2010-Q4       2010.0            15000.0
# 52859        2013-Q1       2013.0          8000000.0
# 52860        2009-Q4       2009.0           195000.0
# 52861        2013-Q3       2013.0                NaN
# 52862        2013-Q3       2013.0          8400000.0
# 52863        2005-Q1       2005.0          2000000.0
# 52864        2009-Q1       2009.0         12000000.0
# 52865        2012-Q3       2012.0          3800000.0
# 52866        2013-Q2       2013.0         10300000.0
# 52867        2010-Q3       2010.0           350000.0
# 52868        2013-Q3       2013.0          8400000.0
# 52869        2012-Q4       2012.0          3000000.0
#
# [52870 rows x 20 columns]

# %%
comp2.columns
# Out:
# Index(['permalink', 'name', 'category_code', 'funding_total_usd', 'status',
#        'country_code', 'state_code', 'region', 'city', 'funding_rounds',
#        'founded_at', 'founded_month', 'founded_quarter', 'founded_year',
#        'first_funding_at', 'last_funding_at', 'last_milestone_at',
#        'days_in_op', 'first_funding_dayinop', 'last_funding_dayinop'],
#       dtype='object')

# %%
comp2.columns=['permalink', 'company_name', 'category_code', 'funding_total_usd', 'status',
       'country_code', 'state_code', 'region', 'city', 'funding_rounds',
       'founded_at', 'founded_month', 'founded_quarter', 'founded_year',
       'first_funding_at', 'last_funding_at', 'last_milestone_at',
       'days_in_op', 'first_funding_dayinop', 'last_funding_dayinop']

# %%
rds.funding_round_type.unique()
# Out:
# array(['series-a', 'angel', 'series-b', 'venture', 'other', 'series-c+',
#        'private-equity', 'post-ipo', 'crowdfunding'], dtype=object)

# %%
rds[rds['funding_round_type']=='crowdfunding'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 1831 to 30536
# Data columns (total 13 columns):
# company_permalink        30 non-null object
# company_name             30 non-null object
# company_category_code    29 non-null object
# company_country_code     30 non-null object
# company_state_code       30 non-null object
# company_region           30 non-null object
# company_city             29 non-null object
# funding_round_type       30 non-null object
# funded_at                30 non-null datetime64[ns]
# funded_month             30 non-null object
# funded_quarter           30 non-null object
# funded_year              30 non-null int64
# raised_amount_usd        29 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(10)
# memory usage: 3.3+ KB

# %%
gp=rds[rds['funding_round_type']=='crowdfunding'].groupby('company_name')

# %%
crowd=pd.DataFrame({'company_name':list(gp.groups.keys())})

# %%
crowd['funded_at']=pd.DataFrame({'funded_at':list(gp['funded_at'].min().values)})

# %%
crowd
# Out:
#                company_name  funded_at
# 0                   App.net 2012-08-12
# 1                  Appy Pie 2013-08-28
# 2      Cloud Imperium Games 2013-09-27
# 3         Dragon Innovation 2013-08-08
# 4             Elevation Lab 2012-02-11
# 5            Exposed Vocals 2013-07-16
# 6          Faraday Bicycles 2012-08-01
# 7                  Formlabs 2012-10-25
# 8                    Fuel3D 2013-09-04
# 9             Glowing Plant 2013-06-08
# 10   Good Times Restaurants 2013-08-21
# 11         Icarus Ascending 2013-09-05
# 12                LUMI Mask 2011-01-06
# 13              NOMAD GOODS 2012-08-27
# 14              NanoSatisfi 2012-07-14
# 15          OLIVERS Apparel 2013-08-30
# 16                     OUYA 2012-08-09
# 17                Oculus VR 2012-01-01
# 18         Perle Bioscience 2013-09-26
# 19                Pressgram 2013-04-15
# 20                   Pressy 2013-09-19
# 21  R.A. Burch Construction 2013-09-09
# 22               SLIC games 2012-10-01
# 23                  Scanadu 2013-06-09
# 24             TinyCircuits 2013-09-04
# 25            Upheaval Arts 2013-09-12
# 26              WealthForge 2013-08-08
# 27     Wikimedia Foundation 2008-03-01

# %%
crowd=pd.merge(crowd,rds[rds['funding_round_type']=='crowdfunding'][['company_name','funded_at','raised_amount_usd']],how='left', on=['company_name','funded_at'])

# %%
crowd
# Out:
#                company_name  funded_at  raised_amount_usd
# 0                   App.net 2012-08-12           500000.0
# 1                  Appy Pie 2013-08-28            10000.0
# 2      Cloud Imperium Games 2013-09-27         20000000.0
# 3         Dragon Innovation 2013-08-08          2145000.0
# 4             Elevation Lab 2012-02-11          1450000.0
# 5            Exposed Vocals 2013-07-16           250000.0
# 6          Faraday Bicycles 2012-08-01           177268.0
# 7                  Formlabs 2012-10-25          2800000.0
# 8                    Fuel3D 2013-09-04           325000.0
# 9             Glowing Plant 2013-06-08           484000.0
# 10   Good Times Restaurants 2013-08-21          5500000.0
# 11         Icarus Ascending 2013-09-05            10000.0
# 12                LUMI Mask 2011-01-06            27000.0
# 13              NOMAD GOODS 2012-08-27           161897.0
# 14              NanoSatisfi 2012-07-14           100000.0
# 15          OLIVERS Apparel 2013-08-30           173000.0
# 16                     OUYA 2012-08-09          8600000.0
# 17                Oculus VR 2012-01-01          2400000.0
# 18         Perle Bioscience 2013-09-26          2000000.0
# 19                Pressgram 2013-04-15            56500.0
# 20                   Pressy 2013-09-19           500000.0
# 21  R.A. Burch Construction 2013-09-09         14600000.0
# 22               SLIC games 2012-10-01            10000.0
# 23                  Scanadu 2013-06-09          1565113.0
# 24             TinyCircuits 2013-09-04           110000.0
# 25            Upheaval Arts 2013-09-12            85000.0
# 26              WealthForge 2013-08-08                NaN
# 27     Wikimedia Foundation 2008-03-01          3000000.0

# %%
crowd.columns =['company_name', 'cr_funded_at', 'cr_raised_amount_usd']

# %%
gp=rds[rds['funding_round_type']=='series-a'].groupby('company_name')
s_a=pd.DataFrame({'company_name':list(gp.groups.keys())})

# %%
gp=rds[rds['funding_round_type']=='series-a'].groupby('company_name')
s_a=pd.DataFrame({'company_name':list(gp.groups.keys())})
s_a['funded_at']=pd.DataFrame({'funded_at':list(gp['funded_at'].min().values)})

# %%
s_a=pd.merge(s_a,rds[rds['funding_round_type']=='series-a'][['company_name','funded_at','raised_amount_usd']],how='left', on=['company_name','funded_at'])

# %%
s_a.columns =['company_name', 'sa_funded_at', 'sa_raised_amount_usd']

# %%
s_a=s_a.drop_duplicates()

# %%
len(s_a['company_name'].drop_duplicates())
# Out:
# 5808

# %%
df=pd.merge(comp2,s_a,how='left', on='company_name')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3186 entries, 0 to 3185
# Data columns (total 22 columns):
# permalink                3186 non-null object
# company_name             3186 non-null object
# category_code            3094 non-null object
# funding_total_usd        3012 non-null object
# status                   3186 non-null object
# country_code             3186 non-null object
# state_code               3148 non-null object
# region                   3186 non-null object
# city                     3160 non-null object
# funding_rounds           3186 non-null int64
# founded_at               3186 non-null datetime64[ns]
# founded_month            3186 non-null object
# founded_quarter          3186 non-null object
# founded_year             3186 non-null float64
# first_funding_at         3172 non-null datetime64[ns]
# last_funding_at          3172 non-null datetime64[ns]
# last_milestone_at        1928 non-null object
# days_in_op               3186 non-null timedelta64[ns]
# first_funding_dayinop    3172 non-null timedelta64[ns]
# last_funding_dayinop     3172 non-null timedelta64[ns]
# sa_funded_at             769 non-null datetime64[ns]
# sa_raised_amount_usd     718 non-null float64
# dtypes: datetime64[ns](4), float64(2), int64(1), object(12), timedelta64[ns](3)
# memory usage: 572.5+ KB

# %%
# df

# %%
df['sa_funded_daysop']=df['sa_funded_at']-df['founded_at']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3186 entries, 0 to 3185
# Data columns (total 23 columns):
# permalink                3186 non-null object
# company_name             3186 non-null object
# category_code            3094 non-null object
# funding_total_usd        3012 non-null object
# status                   3186 non-null object
# country_code             3186 non-null object
# state_code               3148 non-null object
# region                   3186 non-null object
# city                     3160 non-null object
# funding_rounds           3186 non-null int64
# founded_at               3186 non-null datetime64[ns]
# founded_month            3186 non-null object
# founded_quarter          3186 non-null object
# founded_year             3186 non-null float64
# first_funding_at         3172 non-null datetime64[ns]
# last_funding_at          3172 non-null datetime64[ns]
# last_milestone_at        1928 non-null object
# days_in_op               3186 non-null timedelta64[ns]
# first_funding_dayinop    3172 non-null timedelta64[ns]
# last_funding_dayinop     3172 non-null timedelta64[ns]
# sa_funded_at             769 non-null datetime64[ns]
# sa_raised_amount_usd     718 non-null float64
# sa_funded_daysop         769 non-null timedelta64[ns]
# dtypes: datetime64[ns](4), float64(2), int64(1), object(12), timedelta64[ns](4)
# memory usage: 597.4+ KB

# %%
query='''SELECT company_name, min(funded_at) as ag_funded_at, sum(raised_amount_usd) as ag_raised_amount_usd 
            FROM rds
                WHERE funding_round_type = \'angel\'
                GROUP BY company_name'''

# %%
gp=rds[rds['funding_round_type']=='angel'].groupby('company_name')
angel=pd.DataFrame({'company_name':list(gp.groups.keys())})
angel['funded_at']=pd.DataFrame({'funded_at':list(gp['funded_at'].min().values)})
angel=pd.merge(angel,rds[rds['funding_round_type']=='angel'][['company_name','funded_at','raised_amount_usd']],how='left', on=['company_name','funded_at'])

# %%
angel.columns =['company_name', 'ag_funded_at', 'ag_raised_amount_usd']

# %%
gp=rds[rds['funding_round_type']=='venture'].groupby('company_name')
vent=pd.DataFrame({'company_name':list(gp.groups.keys())})
vent['funded_at']=pd.DataFrame({'funded_at':list(gp['funded_at'].min().values)})
vent=pd.merge(vent,rds[rds['funding_round_type']=='venture'][['company_name','funded_at','raised_amount_usd']],how='left', on=['company_name','funded_at'])

# %%
vent.columns=['company_name', 've_funded_at', 've_raised_amount_usd']

# %%
df=pd.merge(df,angel,how='left', on='company_name')

# %%
df=pd.merge(df,vent,how='left', on='company_name')

# %%
df=pd.merge(df,crowd,how='left', on='company_name')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3197 entries, 0 to 3196
# Data columns (total 29 columns):
# permalink                3197 non-null object
# company_name             3197 non-null object
# category_code            3105 non-null object
# funding_total_usd        3020 non-null object
# status                   3197 non-null object
# country_code             3197 non-null object
# state_code               3158 non-null object
# region                   3197 non-null object
# city                     3171 non-null object
# funding_rounds           3197 non-null int64
# founded_at               3197 non-null datetime64[ns]
# founded_month            3197 non-null object
# founded_quarter          3197 non-null object
# founded_year             3197 non-null float64
# first_funding_at         3183 non-null datetime64[ns]
# last_funding_at          3183 non-null datetime64[ns]
# last_milestone_at        1938 non-null object
# days_in_op               3197 non-null timedelta64[ns]
# first_funding_dayinop    3183 non-null timedelta64[ns]
# last_funding_dayinop     3183 non-null timedelta64[ns]
# sa_funded_at             770 non-null datetime64[ns]
# sa_raised_amount_usd     719 non-null float64
# sa_funded_daysop         770 non-null timedelta64[ns]
# ag_funded_at             266 non-null datetime64[ns]
# ag_raised_amount_usd     211 non-null float64
# ve_funded_at             1537 non-null datetime64[ns]
# ve_raised_amount_usd     1412 non-null float64
# cr_funded_at             2 non-null datetime64[ns]
# cr_raised_amount_usd     2 non-null float64
# dtypes: datetime64[ns](7), float64(5), int64(1), object(12), timedelta64[ns](4)
# memory usage: 749.3+ KB

# %%
df['founded_at']=pd.to_datetime(df['founded_at'])

# %%
df['ve_funded_at']=pd.to_datetime(df['ve_funded_at'])

# %%
df['sa_funded_at']=pd.to_datetime(df['sa_funded_at'])

# %%
df['cr_funded_at']=pd.to_datetime(df['cr_funded_at'])# to be run

# %%
df['first_funding_at']=pd.to_datetime(df['first_funding_at'])

# %%
df['cr_funded_daysop']=df['cr_funded_at']-df['founded_at'] # to be run

# %%
df['cr_funded_daysop']=df['cr_funded_daysop'].astype('timedelta64[D]')

# %%
df['sa_funded_daysop']=df['sa_funded_at']-df['founded_at']

# %%
df['ag_funded_daysop']=df['ag_funded_at']-df['founded_at']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3197 entries, 0 to 3196
# Data columns (total 31 columns):
# permalink                3197 non-null object
# company_name             3197 non-null object
# category_code            3105 non-null object
# funding_total_usd        3020 non-null object
# status                   3197 non-null object
# country_code             3197 non-null object
# state_code               3158 non-null object
# region                   3197 non-null object
# city                     3171 non-null object
# funding_rounds           3197 non-null int64
# founded_at               3197 non-null datetime64[ns]
# founded_month            3197 non-null object
# founded_quarter          3197 non-null object
# founded_year             3197 non-null float64
# first_funding_at         3183 non-null datetime64[ns]
# last_funding_at          3183 non-null datetime64[ns]
# last_milestone_at        1938 non-null object
# days_in_op               3197 non-null timedelta64[ns]
# first_funding_dayinop    3183 non-null timedelta64[ns]
# last_funding_dayinop     3183 non-null timedelta64[ns]
# sa_funded_at             770 non-null datetime64[ns]
# sa_raised_amount_usd     719 non-null float64
# sa_funded_daysop         770 non-null timedelta64[ns]
# ag_funded_at             266 non-null datetime64[ns]
# ag_raised_amount_usd     211 non-null float64
# ve_funded_at             1537 non-null datetime64[ns]
# ve_raised_amount_usd     1412 non-null float64
# cr_funded_at             2 non-null datetime64[ns]
# cr_raised_amount_usd     2 non-null float64
# cr_funded_daysop         2 non-null float64
# ag_funded_daysop         266 non-null timedelta64[ns]
# dtypes: datetime64[ns](7), float64(6), int64(1), object(12), timedelta64[ns](5)
# memory usage: 799.2+ KB

# %%
df['ve_funded_daysop']=df['ve_funded_at']-df['founded_at']

# %%
df['first_funding_dayinop']=df['first_funding_at']-df['founded_at']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3197 entries, 0 to 3196
# Data columns (total 32 columns):
# permalink                3197 non-null object
# company_name             3197 non-null object
# category_code            3105 non-null object
# funding_total_usd        3020 non-null object
# status                   3197 non-null object
# country_code             3197 non-null object
# state_code               3158 non-null object
# region                   3197 non-null object
# city                     3171 non-null object
# funding_rounds           3197 non-null int64
# founded_at               3197 non-null datetime64[ns]
# founded_month            3197 non-null object
# founded_quarter          3197 non-null object
# founded_year             3197 non-null float64
# first_funding_at         3183 non-null datetime64[ns]
# last_funding_at          3183 non-null datetime64[ns]
# last_milestone_at        1938 non-null object
# days_in_op               3197 non-null timedelta64[ns]
# first_funding_dayinop    3183 non-null timedelta64[ns]
# last_funding_dayinop     3183 non-null timedelta64[ns]
# sa_funded_at             770 non-null datetime64[ns]
# sa_raised_amount_usd     719 non-null float64
# sa_funded_daysop         770 non-null timedelta64[ns]
# ag_funded_at             266 non-null datetime64[ns]
# ag_raised_amount_usd     211 non-null float64
# ve_funded_at             1537 non-null datetime64[ns]
# ve_raised_amount_usd     1412 non-null float64
# cr_funded_at             2 non-null datetime64[ns]
# cr_raised_amount_usd     2 non-null float64
# cr_funded_daysop         2 non-null float64
# ag_funded_daysop         266 non-null timedelta64[ns]
# ve_funded_daysop         1537 non-null timedelta64[ns]
# dtypes: datetime64[ns](7), float64(6), int64(1), object(12), timedelta64[ns](6)
# memory usage: 824.2+ KB

# %%
df['ag_funded_daysop']=df['ag_funded_daysop'].astype('timedelta64[D]')

# %%
df['ve_funded_daysop']=df['ve_funded_daysop'].astype('timedelta64[D]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3197 entries, 0 to 3196
# Data columns (total 32 columns):
# permalink                3197 non-null object
# company_name             3197 non-null object
# category_code            3105 non-null object
# funding_total_usd        3020 non-null object
# status                   3197 non-null object
# country_code             3197 non-null object
# state_code               3158 non-null object
# region                   3197 non-null object
# city                     3171 non-null object
# funding_rounds           3197 non-null int64
# founded_at               3197 non-null datetime64[ns]
# founded_month            3197 non-null object
# founded_quarter          3197 non-null object
# founded_year             3197 non-null float64
# first_funding_at         3183 non-null datetime64[ns]
# last_funding_at          3183 non-null datetime64[ns]
# last_milestone_at        1938 non-null object
# days_in_op               3197 non-null timedelta64[ns]
# first_funding_dayinop    3183 non-null timedelta64[ns]
# last_funding_dayinop     3183 non-null timedelta64[ns]
# sa_funded_at             770 non-null datetime64[ns]
# sa_raised_amount_usd     719 non-null float64
# sa_funded_daysop         770 non-null timedelta64[ns]
# ag_funded_at             266 non-null datetime64[ns]
# ag_raised_amount_usd     211 non-null float64
# ve_funded_at             1537 non-null datetime64[ns]
# ve_raised_amount_usd     1412 non-null float64
# cr_funded_at             2 non-null datetime64[ns]
# cr_raised_amount_usd     2 non-null float64
# cr_funded_daysop         2 non-null float64
# ag_funded_daysop         266 non-null float64
# ve_funded_daysop         1537 non-null float64
# dtypes: datetime64[ns](7), float64(8), int64(1), object(12), timedelta64[ns](4)
# memory usage: 824.2+ KB

# %%
df['state_code'].value_counts()[:5]
# Out:
# CA    1157
# MA     315
# NY     216
# TX     173
# WA     115
# Name: state_code, dtype: int64

# %%
ind=df[df['state_code']=='CA'].index
df['CA']=0
df['CA'].iloc[ind]=1
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
ind=df[df['state_code']=='NY'].index
df['NY']=0
df['NY'].iloc[ind]=1

ind=df[df['state_code']=='MA'].index
df['MA']=0
df['MA'].iloc[ind]=1

ind=df[df['state_code']=='TX'].index
df['TX']=0
df['TX'].iloc[ind]=1

ind=df[df['state_code']=='WA'].index
df['WA']=0
df['WA'].iloc[ind]=1
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df['country_code'].value_counts()[:5]
# Out:
# USA    3197
# Name: country_code, dtype: int64

# %%
df['founded_year'] = df['founded_at'].dt.year
df['founded_month'] = df['founded_at'].dt.month

# %%
df['sa_funded_daysop']=df['sa_funded_daysop'].astype('timedelta64[D]')

# %%
df['first_funding_dayinop']=df['first_funding_dayinop'].astype('timedelta64[D]')

# %%
inf=pd.read_csv('./data/inflation.csv')

# %%
df['founded_year']=df['founded_year'].astype(int)

# %%
inf['founded_year']=inf['YEAR']

# %%
df=pd.merge(df,inf[['founded_year', 'AVE']],how='left', on='founded_year')# AVE is the annual average inflation

# %%
cpi=pd.read_csv('./data/cpi.csv')

# %%
cpi['founded_year']=cpi['YEAR']

# %%
cpi[['founded_year','adj_base2018']].head()
# Out:
#    founded_year  adj_base2018
# 0        2018.0          1.00
# 1        2017.0          0.97
# 2        2016.0          0.95
# 3        2015.0          0.94
# 4        2014.0          0.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3197 entries, 0 to 3196
# Data columns (total 38 columns):
# permalink                3197 non-null object
# company_name             3197 non-null object
# category_code            3105 non-null object
# funding_total_usd        3020 non-null object
# status                   3197 non-null object
# country_code             3197 non-null object
# state_code               3158 non-null object
# region                   3197 non-null object
# city                     3171 non-null object
# funding_rounds           3197 non-null int64
# founded_at               3197 non-null datetime64[ns]
# founded_month            3197 non-null int64
# founded_quarter          3197 non-null object
# founded_year             3197 non-null int64
# first_funding_at         3183 non-null datetime64[ns]
# last_funding_at          3183 non-null datetime64[ns]
# last_milestone_at        1938 non-null object
# days_in_op               3197 non-null timedelta64[ns]
# first_funding_dayinop    3183 non-null float64
# last_funding_dayinop     3183 non-null timedelta64[ns]
# sa_funded_at             770 non-null datetime64[ns]
# sa_raised_amount_usd     719 non-null float64
# sa_funded_daysop         770 non-null float64
# ag_funded_at             266 non-null datetime64[ns]
# ag_raised_amount_usd     211 non-null float64
# ve_funded_at             1537 non-null datetime64[ns]
# ve_raised_amount_usd     1412 non-null float64
# cr_funded_at             2 non-null datetime64[ns]
# cr_raised_amount_usd     2 non-null float64
# cr_funded_daysop         2 non-null float64
# ag_funded_daysop         266 non-null float64
# ve_funded_daysop         1537 non-null float64
# CA                       3197 non-null int64
# NY                       3197 non-null int64
# MA                       3197 non-null int64
# TX                       3197 non-null int64
# WA                       3197 non-null int64
# AVE                      3192 non-null float64
# dtypes: datetime64[ns](7), float64(10), int64(8), object(11), timedelta64[ns](2)
# memory usage: 974.1+ KB

# %%
df.columns
# Out:
# Index(['permalink', 'company_name', 'category_code', 'funding_total_usd',
#        'status', 'country_code', 'state_code', 'region', 'city',
#        'funding_rounds', 'founded_at', 'founded_month', 'founded_quarter',
#        'founded_year', 'first_funding_at', 'last_funding_at',
#        'last_milestone_at', 'days_in_op', 'first_funding_dayinop',
#        'last_funding_dayinop', 'sa_funded_at', 'sa_raised_amount_usd',
#        'sa_funded_daysop', 'ag_funded_at', 'ag_raised_amount_usd',
#        've_funded_at', 've_raised_amount_usd', 'cr_funded_at',
#        'cr_raised_amount_usd', 'cr_funded_daysop', 'ag_funded_daysop',
#        've_funded_daysop', 'CA', 'NY', 'MA', 'TX', 'WA', 'AVE'],
#       dtype='object')

# %%
df.columns=['permalink', 'company_name', 'category_code', 'funding_total_usd',
       'status', 'country_code', 'state_code', 'region', 'city',
       'funding_rounds', 'founded_at', 'founded_month', 'founded_quarter',
       'founded_year', 'first_funding_at', 'last_funding_at',
       'last_milestone_at', 'days_in_op', 'first_funding_dayinop',
       'last_funding_dayinop', 'sa_funded_at', 'sa_raised_amount_usd',
       'sa_funded_daysop', 'ag_funded_at', 'ag_raised_amount_usd',
       've_funded_at', 've_raised_amount_usd', 'cr_funded_at',
       'cr_raised_amount_usd', 'cr_funded_daysop', 'ag_funded_daysop',
       've_funded_daysop', 'CA', 'NY', 'MA', 'TX', 'WA', 'ave_inf_y']

# %%
df=pd.merge(df,cpi[['founded_year','adj_base2018']],how='left', on='founded_year')# CPIt/CPI_2018, CPI consumer price index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3197 entries, 0 to 3196
# Data columns (total 39 columns):
# permalink                3197 non-null object
# company_name             3197 non-null object
# category_code            3105 non-null object
# funding_total_usd        3020 non-null object
# status                   3197 non-null object
# country_code             3197 non-null object
# state_code               3158 non-null object
# region                   3197 non-null object
# city                     3171 non-null object
# funding_rounds           3197 non-null int64
# founded_at               3197 non-null datetime64[ns]
# founded_month            3197 non-null int64
# founded_quarter          3197 non-null object
# founded_year             3197 non-null int64
# first_funding_at         3183 non-null datetime64[ns]
# last_funding_at          3183 non-null datetime64[ns]
# last_milestone_at        1938 non-null object
# days_in_op               3197 non-null timedelta64[ns]
# first_funding_dayinop    3183 non-null float64
# last_funding_dayinop     3183 non-null timedelta64[ns]
# sa_funded_at             770 non-null datetime64[ns]
# sa_raised_amount_usd     719 non-null float64
# sa_funded_daysop         770 non-null float64
# ag_funded_at             266 non-null datetime64[ns]
# ag_raised_amount_usd     211 non-null float64
# ve_funded_at             1537 non-null datetime64[ns]
# ve_raised_amount_usd     1412 non-null float64
# cr_funded_at             2 non-null datetime64[ns]
# cr_raised_amount_usd     2 non-null float64
# cr_funded_daysop         2 non-null float64
# ag_funded_daysop         266 non-null float64
# ve_funded_daysop         1537 non-null float64
# CA                       3197 non-null int64
# NY                       3197 non-null int64
# MA                       3197 non-null int64
# TX                       3197 non-null int64
# WA                       3197 non-null int64
# ave_inf_y                3192 non-null float64
# adj_base2018             3192 non-null float64
# dtypes: datetime64[ns](7), float64(11), int64(8), object(11), timedelta64[ns](2)
# memory usage: 999.1+ KB

# %%
df['sa_raised_amount_usd_adj']=df['sa_raised_amount_usd']*df['adj_base2018']

# %%
df['ag_raised_amount_usd_adj']=df['ag_raised_amount_usd']*df['adj_base2018']

# %%
df['ve_raised_amount_usd_adj']=df['ve_raised_amount_usd']*df['adj_base2018']

# %%
df['cr_raised_amount_usd_adj']=df['cr_raised_amount_usd']*df['adj_base2018']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3197 entries, 0 to 3196
# Data columns (total 43 columns):
# permalink                   3197 non-null object
# company_name                3197 non-null object
# category_code               3105 non-null object
# funding_total_usd           3020 non-null object
# status                      3197 non-null object
# country_code                3197 non-null object
# state_code                  3158 non-null object
# region                      3197 non-null object
# city                        3171 non-null object
# funding_rounds              3197 non-null int64
# founded_at                  3197 non-null datetime64[ns]
# founded_month               3197 non-null int64
# founded_quarter             3197 non-null object
# founded_year                3197 non-null int64
# first_funding_at            3183 non-null datetime64[ns]
# last_funding_at             3183 non-null datetime64[ns]
# last_milestone_at           1938 non-null object
# days_in_op                  3197 non-null timedelta64[ns]
# first_funding_dayinop       3183 non-null float64
# last_funding_dayinop        3183 non-null timedelta64[ns]
# sa_funded_at                770 non-null datetime64[ns]
# sa_raised_amount_usd        719 non-null float64
# sa_funded_daysop            770 non-null float64
# ag_funded_at                266 non-null datetime64[ns]
# ag_raised_amount_usd        211 non-null float64
# ve_funded_at                1537 non-null datetime64[ns]
# ve_raised_amount_usd        1412 non-null float64
# cr_funded_at                2 non-null datetime64[ns]
# cr_raised_amount_usd        2 non-null float64
# cr_funded_daysop            2 non-null float64
# ag_funded_daysop            266 non-null float64
# ve_funded_daysop            1537 non-null float64
# CA                          3197 non-null int64
# NY                          3197 non-null int64
# MA                          3197 non-null int64
# TX                          3197 non-null int64
# WA                          3197 non-null int64
# ave_inf_y                   3192 non-null float64
# adj_base2018                3192 non-null float64
# sa_raised_amount_usd_adj    719 non-null float64
# ag_raised_amount_usd_adj    211 non-null float64
# ve_raised_amount_usd_adj    1411 non-null float64
# cr_raised_amount_usd_adj    2 non-null float64
# dtypes: datetime64[ns](7), float64(15), int64(8), object(11), timedelta64[ns](2)
# memory usage: 1.1+ MB

# %%
df=df.dropna(subset=['category_code', 'status','first_funding_dayinop', 'founded_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3091 entries, 0 to 3196
# Data columns (total 43 columns):
# permalink                   3091 non-null object
# company_name                3091 non-null object
# category_code               3091 non-null object
# funding_total_usd           2923 non-null object
# status                      3091 non-null object
# country_code                3091 non-null object
# state_code                  3054 non-null object
# region                      3091 non-null object
# city                        3066 non-null object
# funding_rounds              3091 non-null int64
# founded_at                  3091 non-null datetime64[ns]
# founded_month               3091 non-null int64
# founded_quarter             3091 non-null object
# founded_year                3091 non-null int64
# first_funding_at            3091 non-null datetime64[ns]
# last_funding_at             3091 non-null datetime64[ns]
# last_milestone_at           1893 non-null object
# days_in_op                  3091 non-null timedelta64[ns]
# first_funding_dayinop       3091 non-null float64
# last_funding_dayinop        3091 non-null timedelta64[ns]
# sa_funded_at                749 non-null datetime64[ns]
# sa_raised_amount_usd        698 non-null float64
# sa_funded_daysop            749 non-null float64
# ag_funded_at                262 non-null datetime64[ns]
# ag_raised_amount_usd        207 non-null float64
# ve_funded_at                1499 non-null datetime64[ns]
# ve_raised_amount_usd        1376 non-null float64
# cr_funded_at                2 non-null datetime64[ns]
# cr_raised_amount_usd        2 non-null float64
# cr_funded_daysop            2 non-null float64
# ag_funded_daysop            262 non-null float64
# ve_funded_daysop            1499 non-null float64
# CA                          3091 non-null int64
# NY                          3091 non-null int64
# MA                          3091 non-null int64
# TX                          3091 non-null int64
# WA                          3091 non-null int64
# ave_inf_y                   3086 non-null float64
# adj_base2018                3086 non-null float64
# sa_raised_amount_usd_adj    698 non-null float64
# ag_raised_amount_usd_adj    207 non-null float64
# ve_raised_amount_usd_adj    1375 non-null float64
# cr_raised_amount_usd_adj    2 non-null float64
# dtypes: datetime64[ns](7), float64(15), int64(8), object(11), timedelta64[ns](2)
# memory usage: 1.0+ MB

# %%
df_model=df[['status','category_code', 'CA', 'NY','MA', 'TX', 'WA', 'founded_month', 'first_funding_dayinop',
        'ave_inf_y', 'ag_funded_daysop', 'ag_raised_amount_usd_adj', 'cr_funded_daysop', 'cr_raised_amount_usd_adj']]

# %%
df_model=df_model.drop_duplicates()

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3074 entries, 0 to 3196
# Data columns (total 14 columns):
# status                      3074 non-null object
# category_code               3074 non-null object
# CA                          3074 non-null int64
# NY                          3074 non-null int64
# MA                          3074 non-null int64
# TX                          3074 non-null int64
# WA                          3074 non-null int64
# founded_month               3074 non-null int64
# first_funding_dayinop       3074 non-null float64
# ave_inf_y                   3069 non-null float64
# ag_funded_daysop            259 non-null float64
# ag_raised_amount_usd_adj    206 non-null float64
# cr_funded_daysop            2 non-null float64
# cr_raised_amount_usd_adj    2 non-null float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 360.2+ KB

# %%
df_model=df_model.fillna(0)

# %%
df_model.to_csv('./data/start-up_mod.csv')

# %%
y=df['sa_funded_daysop']
plt.hist(y, range=(y.min(), y.max()));
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
y.describe()
# Out:
# count      749.000000
# mean      2833.607477
# std       2565.646618
# min     -12874.000000
# 25%       1127.000000
# 50%       2321.000000
# 75%       3810.000000
# max      21946.000000
# Name: sa_funded_daysop, dtype: float64

# %%
#second model including Series A funding
df_model2=df[['company_name','status','category_code', 'CA', 'NY','MA', 'TX', 'WA', 'founded_month', 'first_funding_dayinop',
        'ave_inf_y', 'ag_funded_daysop', 'ag_raised_amount_usd_adj', 'cr_funded_daysop', 'cr_raised_amount_usd_adj',
        'sa_funded_daysop','sa_raised_amount_usd_adj']]

# %%
df_model2=df_model2.fillna(0)

# %%
df_model2=df_model2[df_model2['sa_funded_daysop']>=0]

# %%
# removing funding that occured hafter 10 years of operation
df_model2=df_model2.reset_index()

# %%
ind=df_model2[df_model2['sa_funded_daysop']>(10*365)].index

# %%
df_model2['sa_funded_daysop'].iloc[ind]=0
df_model2['sa_raised_amount_usd_adj'].iloc[ind]=0
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_model2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3082 entries, 0 to 3081
# Data columns (total 18 columns):
# index                       3082 non-null int64
# company_name                3082 non-null object
# status                      3082 non-null object
# category_code               3082 non-null object
# CA                          3082 non-null int64
# NY                          3082 non-null int64
# MA                          3082 non-null int64
# TX                          3082 non-null int64
# WA                          3082 non-null int64
# founded_month               3082 non-null int64
# first_funding_dayinop       3082 non-null float64
# ave_inf_y                   3082 non-null float64
# ag_funded_daysop            3082 non-null float64
# ag_raised_amount_usd_adj    3082 non-null float64
# cr_funded_daysop            3082 non-null float64
# cr_raised_amount_usd_adj    3082 non-null float64
# sa_funded_daysop            3082 non-null float64
# sa_raised_amount_usd_adj    3082 non-null float64
# dtypes: float64(8), int64(7), object(3)
# memory usage: 433.5+ KB

# %%
y=df_model2['sa_funded_daysop']
plt.hist(y, range=(y.min(), y.max()));

# %%
y.max()
# Out:
# 3639.0

# %%
df_model2.to_csv('./data/start-up_mod_w_sa.csv')

# %%
# !ls /Users/carolina/start-up-classification/data
# Out:
# CPI.csv                     crunchbase-rounds.csv
# crunchbase-acquisitions.csv inflation.csv
# crunchbase-companies.csv    start-up_mod.csv
# crunchbase-investments.csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3091 entries, 0 to 3196
# Data columns (total 43 columns):
# permalink                   3091 non-null object
# company_name                3091 non-null object
# category_code               3091 non-null object
# funding_total_usd           2923 non-null object
# status                      3091 non-null object
# country_code                3091 non-null object
# state_code                  3054 non-null object
# region                      3091 non-null object
# city                        3066 non-null object
# funding_rounds              3091 non-null int64
# founded_at                  3091 non-null datetime64[ns]
# founded_month               3091 non-null int64
# founded_quarter             3091 non-null object
# founded_year                3091 non-null int64
# first_funding_at            3091 non-null datetime64[ns]
# last_funding_at             3091 non-null datetime64[ns]
# last_milestone_at           1893 non-null object
# days_in_op                  3091 non-null timedelta64[ns]
# first_funding_dayinop       3091 non-null float64
# last_funding_dayinop        3091 non-null timedelta64[ns]
# sa_funded_at                749 non-null datetime64[ns]
# sa_raised_amount_usd        698 non-null float64
# sa_funded_daysop            749 non-null float64
# ag_funded_at                262 non-null datetime64[ns]
# ag_raised_amount_usd        207 non-null float64
# ve_funded_at                1499 non-null datetime64[ns]
# ve_raised_amount_usd        1376 non-null float64
# cr_funded_at                2 non-null datetime64[ns]
# cr_raised_amount_usd        2 non-null float64
# cr_funded_daysop            2 non-null float64
# ag_funded_daysop            262 non-null float64
# ve_funded_daysop            1499 non-null float64
# CA                          3091 non-null int64
# NY                          3091 non-null int64
# MA                          3091 non-null int64
# TX                          3091 non-null int64
# WA                          3091 non-null int64
# ave_inf_y                   3086 non-null float64
# adj_base2018                3086 non-null float64
# sa_raised_amount_usd_adj    698 non-null float64
# ag_raised_amount_usd_adj    207 non-null float64
# ve_raised_amount_usd_adj    1375 non-null float64
# cr_raised_amount_usd_adj    2 non-null float64
# dtypes: datetime64[ns](7), float64(15), int64(8), object(11), timedelta64[ns](2)
# memory usage: 1.0+ MB

# %%
df2=df[['company_name','founded_at','status','category_code', 'CA', 'NY','MA', 'TX', 'WA', 'founded_month', 'first_funding_dayinop',
        'ave_inf_y', 'ag_funded_daysop', 'ag_raised_amount_usd_adj', 'cr_funded_daysop', 'cr_raised_amount_usd_adj']]

# %%
adq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6185 entries, 0 to 6184
# Data columns (total 20 columns):
# company_permalink         4651 non-null object
# company_name              4651 non-null object
# company_category_code     3933 non-null object
# company_country_code      4651 non-null object
# company_state_code        4543 non-null object
# company_region            4651 non-null object
# company_city              4532 non-null object
# acquirer_permalink        4651 non-null object
# acquirer_name             4651 non-null object
# acquirer_category_code    4137 non-null object
# acquirer_country_code     4384 non-null object
# acquirer_state_code       3877 non-null object
# acquirer_region           4651 non-null object
# acquirer_city             4262 non-null object
# acquired_at               4651 non-null object
# acquired_month            4651 non-null object
# acquired_quarter          4651 non-null object
# acquired_year             4651 non-null float64
# price_amount              1409 non-null float64
# price_currency_code       4648 non-null object
# dtypes: float64(2), object(18)
# memory usage: 966.5+ KB

# %%
adq['acquired_at']=pd.to_datetime(adq['acquired_at'])

# %%
df2=df2.drop_duplicates()

# %%
df2=pd.merge(df2,adq[['company_name','acquired_at']],how='left',on='company_name')

# %%
df2['adq_daysonop']=df2['acquired_at']-df2['founded_at']

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3098 entries, 0 to 3097
# Data columns (total 18 columns):
# company_name                3098 non-null object
# founded_at                  3098 non-null datetime64[ns]
# status                      3098 non-null object
# category_code               3098 non-null object
# CA                          3098 non-null int64
# NY                          3098 non-null int64
# MA                          3098 non-null int64
# TX                          3098 non-null int64
# WA                          3098 non-null int64
# founded_month               3098 non-null int64
# first_funding_dayinop       3098 non-null float64
# ave_inf_y                   3093 non-null float64
# ag_funded_daysop            262 non-null float64
# ag_raised_amount_usd_adj    206 non-null float64
# cr_funded_daysop            2 non-null float64
# cr_raised_amount_usd_adj    2 non-null float64
# acquired_at                 545 non-null datetime64[ns]
# adq_daysonop                545 non-null timedelta64[ns]
# dtypes: datetime64[ns](2), float64(6), int64(6), object(3), timedelta64[ns](1)
# memory usage: 459.9+ KB

# %%
y=df2[df2['status']=='acquired']['adq_daysonop']/timedelta(days=1)

# %%
y.describe()
# Out:
# count      545.000000
# mean      4082.108257
# std       2245.003046
# min        393.000000
# 25%       2827.000000
# 50%       3666.000000
# 75%       4739.000000
# max      23425.000000
# Name: adq_daysonop, dtype: float64

# %%
plt.hist(y, range=(y.min(), y.max()));
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
4741.75/365
# Out:
# 12.991095890410959

# %%
y=df2[df2['status']=='acquired']['adq_daysonop']/timedelta(days=1)
x=df2[df2['status']=='acquired']['category_code']

# %%
plt.figure(figsize= [10,10])
plt.scatter(y,x)

# %%
x.describe()
# Out:
# count          547
# unique          27
# top       software
# freq           153
# Name: category_code, dtype: object

# %%
soft=df2[df2['category_code']=='software']

# %%
# percentace of software companies that are adquired
len(soft[soft['status']=='acquired'])/len(soft)
# Out:
# 0.19490445859872613

# %%
#percentage of web companies that are adquired
len(df2[df2['category_code']=='web'][df2['status']=='acquired'])/len(df2[df2['category_code']=='web'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 0.3

# %%
test=pd.get_dummies(df2[['category_code']])

# %%
# top 10 categories by number of companies
test.sum().sort_values(ascending=False)[:10]
# Out:
# category_code_software           785
# category_code_biotech            383
# category_code_enterprise         179
# category_code_web                160
# category_code_hardware           145
# category_code_mobile             134
# category_code_semiconductor      125
# category_code_cleantech          114
# category_code_ecommerce          109
# category_code_network_hosting    100
# dtype: int64

# %%
# top 10 categories by number of companies acquired
pd.get_dummies(df2[df2['status']=='acquired']['category_code']).sum().sort_values(ascending=False)[:10]
# Out:
# software            153
# web                  48
# biotech              45
# mobile               39
# enterprise           36
# semiconductor        28
# network_hosting      26
# public_relations     26
# security             23
# hardware             23
# dtype: int64

# %%
# top 20 categories by percentage of companies acquired
(pd.get_dummies(df2[df2['status']=='acquired']['category_code']).sum()/pd.get_dummies(df2['category_code']).sum()).sort_values(ascending=False)[:20]
# Out:
# sports              0.500000
# web                 0.300000
# mobile              0.291045
# public_relations    0.282609
# security            0.267442
# search              0.263158
# network_hosting     0.260000
# photo_video         0.250000
# advertising         0.243902
# games_video         0.230769
# semiconductor       0.224000
# enterprise          0.201117
# software            0.194904
# hardware            0.158621
# other               0.142857
# biotech             0.117493
# ecommerce           0.110092
# cleantech           0.105263
# messaging           0.100000
# consulting          0.098361
# dtype: float64

# %%
# top 10 categories by number of companies ipo
pd.get_dummies(df2[df2['status']=='ipo']['category_code']).sum().sort_values(ascending=False)[:10]
# Out:
# biotech            28
# software           27
# web                11
# network_hosting    10
# cleantech           9
# mobile              8
# hardware            8
# semiconductor       7
# security            6
# ecommerce           6
# dtype: int64

# %%
# top 20 categories by percentage of companies ipo
(pd.get_dummies(df2[df2['status']=='ipo']['category_code']).sum()/pd.get_dummies(df2['category_code']).sum()).sort_values(ascending=False)[:20]
# Out:
# music              0.250000
# messaging          0.200000
# finance            0.161290
# news               0.142857
# hospitality        0.111111
# search             0.105263
# automotive         0.100000
# network_hosting    0.100000
# nanotech           0.090909
# transportation     0.090909
# cleantech          0.078947
# biotech            0.073107
# security           0.069767
# web                0.068750
# other              0.063492
# advertising        0.060976
# mobile             0.059701
# medical            0.057471
# semiconductor      0.056000
# hardware           0.055172
# dtype: float64

# %%
df2[(df2['category_code']=='music') & (df2['status']=='ipo')]
# Out:
#        company_name founded_at status category_code  CA  NY  MA  TX  WA  \
# 2004  Pandora Media 2000-01-01    ipo         music   1   0   0   0   0
#
#       founded_month  first_funding_dayinop  ave_inf_y  ag_funded_daysop  \
# 2004              1                   61.0  16.393939               NaN
#
#       ag_raised_amount_usd_adj  cr_funded_daysop  cr_raised_amount_usd_adj  \
# 1846   0   0              1                 5145.0  15.464646
# 1932   0   0              1                 5243.0  15.464646
# 2117   0   0              1                 3012.0  17.169697
# 2140   0   0              1                11644.0   5.585859
# 2175   0   0              1                 2870.0  15.464646
# 2272   0   0              1                 3272.0  16.888889
# 2360   0   0              1                 6841.0  14.393939
# 2590   0   0              1                 5052.0  15.828283
# 2640   0   0              1                 3660.0  16.393939
# 2661   0   1              1                 4154.0  15.828283
# 3068   0   0              1                 4197.0  16.393939
#
#       ag_funded_daysop  ag_raised_amount_usd_adj  cr_funded_daysop  \
# 5               5515.0                   43680.0               NaN
# 48                 NaN                       NaN               NaN
# 139                NaN                       NaN               NaN
# 171                NaN                       NaN               NaN
# 179                NaN                       NaN               NaN
# 378                NaN                       NaN               NaN
# 422                NaN                       NaN               NaN
# 551                NaN                       NaN               NaN
# 639                NaN                       NaN               NaN
# 1050               NaN                       NaN               NaN
# 1093               NaN                       NaN               NaN
# 1101               NaN                       NaN               NaN
# 1275               NaN                       NaN               NaN
# 1393            5065.0                  710023.6               NaN
# 1467               NaN                       NaN               NaN
# 1533               NaN                       NaN               NaN
# 1781               NaN                       NaN               NaN
# 1846            5201.0                  633750.0               NaN
# 1932               NaN                       NaN               NaN
# 2117               NaN                       NaN               NaN
# 2140           12455.0                  208000.0               NaN
# 2175               NaN                       NaN               NaN
# 2272               NaN                       NaN               NaN
# 2360               NaN                       NaN               NaN
# 2590               NaN                       NaN               NaN
# 2640               NaN                       NaN               NaN
# 2661               NaN                       NaN               NaN
# 3068               NaN                       NaN               NaN
#
#       cr_raised_amount_usd_adj acquired_at adq_daysonop
# 5                          NaN         NaT          NaT
# 48                         NaN         NaT          NaT
# 139                        NaN         NaT          NaT
# 171                        NaN         NaT          NaT
# 179                        NaN         NaT          NaT
# 378                        NaN         NaT          NaT
# 422                        NaN         NaT          NaT
# 551                        NaN         NaT          NaT
# 639                        NaN         NaT          NaT
# 1050                       NaN         NaT          NaT
# 1093                       NaN         NaT          NaT
# 1101                       NaN         NaT          NaT
# 1275                       NaN         NaT          NaT
# 1393                       NaN         NaT          NaT
# 1467                       NaN         NaT          NaT
# 1533                       NaN         NaT          NaT
# 1781                       NaN         NaT          NaT
# 1846                       NaN         NaT          NaT
# 1932                       NaN         NaT          NaT
# 2117                       NaN         NaT          NaT
# 2140                       NaN         NaT          NaT
# 2175                       NaN         NaT          NaT
# 2272                       NaN         NaT          NaT
# 2360                       NaN         NaT          NaT
# 2590                       NaN         NaT          NaT
# 2640                       NaN         NaT          NaT
# 2661                       NaN         NaT          NaT
# 3068                       NaN         NaT          NaT

# %%
df2[(df2['category_code']=='software') & (df2['status']=='ipo')]
# Out:
#               company_name founded_at status category_code  CA  NY  MA  TX  \
# 8               3D Systems 1986-01-01    ipo      software   0   0   0   0
# 61          ACTIVE Network 1999-08-01    ipo      software   1   0   0   0
# 269         Asure Software 1985-01-01    ipo      software   0   0   0   1
# 455     Bridgeline Digital 2000-01-01    ipo      software   0   0   1   0
# 455                  102000.00               NaN                       NaN
# 470                        NaN               NaN                       NaN
# 501                        NaN               NaN                       NaN
# 689                        NaN               NaN                       NaN
# 703                        NaN               NaN                       NaN
# 745                  601919.34               NaN                       NaN
# 793                        NaN               NaN                       NaN
# 1301                       NaN               NaN                       NaN
# 1450                       NaN               NaN                       NaN
# 1560                       NaN               NaN                       NaN
# 1579                       NaN               NaN                       NaN
# 2061                       NaN               NaN                       NaN
# 2157                       NaN               NaN                       NaN
# 2191                       NaN               NaN                       NaN
# 2256                       NaN               NaN                       NaN
# 2290                       NaN               NaN                       NaN
# 2391                       NaN               NaN                       NaN
# 2412                       NaN               NaN                       NaN
# 2525                       NaN               NaN                       NaN
# 2570                       NaN               NaN                       NaN
# 2648                       NaN               NaN                       NaN
# 2966                       NaN               NaN                       NaN
# 2981                       NaN               NaN                       NaN
# 3025                       NaN               NaN                       NaN
#
#      acquired_at adq_daysonop
# 8            NaT          NaT
# 61           NaT          NaT
# 269          NaT          NaT
# 455          NaT          NaT
# 470          NaT          NaT
# 501          NaT          NaT
# 689          NaT          NaT
# 703          NaT          NaT
# 745          NaT          NaT
# 793          NaT          NaT
# 1301         NaT          NaT
# 1450         NaT          NaT
# 1560         NaT          NaT
# 1579         NaT          NaT
# 2061         NaT          NaT
# 2157         NaT          NaT
# 2191         NaT          NaT
# 2256         NaT          NaT
# 2290         NaT          NaT
# 2391         NaT          NaT
# 2412         NaT          NaT
# 2525         NaT          NaT
# 2570         NaT          NaT
# 2648         NaT          NaT
# 2966         NaT          NaT
# 2981         NaT          NaT
# 3025         NaT          NaT

# %%
df2[(df2['category_code']=='web') & (df2['status']=='ipo')]
# Out:
#                       company_name founded_at status category_code  CA  NY  \
# 186                   Angie's List 1995-01-01    ipo           web   0   0
# 195                            AOL 1985-05-24    ipo           web   0   1
# 489                     Cafe Press 1999-10-01    ipo           web   1   0
# 669                       comScore 1999-08-01    ipo           web   0   0
# 875                           eBay 1995-09-01    ipo           web   1   0
# 1945                Onstream Media 1993-01-01    ipo           web   0   0
# 1950                     OpenTable 1998-07-02    ipo           web   1   0
# 2205                       Quepasa 1997-06-01    ipo           web   0   0
# 2398  Scripps Networks Interactive 1994-01-01    ipo           web   0   0
# 3045                      XO Group 1996-01-01    ipo           web   0   1
# 3058                        Yahoo! 1994-01-01    ipo           web   1   0
#
#       MA  TX  WA  founded_month  first_funding_dayinop  ave_inf_y  \
# 186    0   0   0              1                 4169.0  14.393939
# 195    0   0   0              5                 7496.0   9.868687
# 489    0   0   0             10                  152.0  15.828283
# 669    0   0   0              8                  397.0  15.828283
# 875    0   0   0              9                  639.0  14.393939
# 1945   0   0   0              1                 6475.0  13.595960
# 1950   0   0   0              7                  303.0  15.464646
# 2205   0   0   0              6                 3895.0  15.212121
# 2398   0   0   0              1                 5903.0  13.969697
# 3045   0   0   0              1                    0.0  14.848485
# 3058   0   0   0              1                  455.0  13.969697
#
#       ag_funded_daysop  ag_raised_amount_usd_adj  cr_funded_daysop  \
# 186                NaN                       NaN               NaN
# 195                NaN                       NaN               NaN
# 489                NaN                       NaN               NaN
# 669                NaN                       NaN               NaN
# 875                NaN                       NaN               NaN
# 1945               NaN                       NaN               NaN
# 1950               NaN                       NaN               NaN
# 2205               NaN                       NaN               NaN
# 2398               NaN                       NaN               NaN
# 3045               NaN                       NaN               NaN
# 3058               NaN                       NaN               NaN
#
#       cr_raised_amount_usd_adj acquired_at adq_daysonop
# 186                        NaN         NaT          NaT
# 195                        NaN         NaT          NaT
# 489                        NaN         NaT          NaT
# 669                        NaN         NaT          NaT
# 875                        NaN         NaT          NaT
# 1945                       NaN         NaT          NaT
# 1950                       NaN         NaT          NaT
# 2205                       NaN         NaT          NaT
# 2398                       NaN         NaT          NaT
# 3045                       NaN         NaT          NaT
# 3058                       NaN         NaT          NaT

# %%
comp.columns=['permalink', 'company_name', 'category_code', 'funding_total_usd', 'status',
       'country_code', 'state_code', 'region', 'city', 'funding_rounds',
       'founded_at', 'founded_month', 'founded_quarter', 'founded_year',
       'first_funding_at', 'last_funding_at', 'last_milestone_at',
       'days_in_op']

# %%
df3=pd.merge(comp,adq[['company_name','acquired_at']],how='left',on='company_name')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17765 entries, 0 to 17764
# Data columns (total 19 columns):
# permalink            17765 non-null object
# company_name         17765 non-null object
# category_code        17365 non-null object
# funding_total_usd    16255 non-null object
# status               17765 non-null object
# country_code         17765 non-null object
# state_code           17516 non-null object
# region               17765 non-null object
# city                 17500 non-null object
# funding_rounds       17765 non-null int64
# founded_at           13710 non-null datetime64[ns]
# founded_month        13710 non-null object
# founded_quarter      13710 non-null object
# founded_year         13710 non-null float64
# first_funding_at     17659 non-null object
# last_funding_at      17659 non-null object
# last_milestone_at    10559 non-null object
# days_in_op           13710 non-null timedelta64[ns]
# acquired_at          1707 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(14), timedelta64[ns](1)
# memory usage: 2.7+ MB

# %%
df3['adq_daysonop']=df3['acquired_at']-df3['founded_at']

# %%
df3['adq_daysonop']=df3['adq_daysonop'].astype('timedelta64[D]')

# %%
df3=df3[df3['adq_daysonop']>0]

# %%
df3=df3.dropna(subset=['category_code', 'status','founded_at'])

# %%
len(df3[df3['status']=='acquired'])
# Out:
# 1368

# %%
y=df3[df3['status']=='acquired']['adq_daysonop']
x=df3[df3['status']=='acquired']['category_code']

# %%
plt.figure(figsize= [11,11])
plt.hist(y, range=(y.min(), y.max()),edgecolor='black', color='royalblue')
plt.title("Company time in opeartion at acquisition", size = 25)
plt.xlabel('days', size = 20, labelpad = 15)
plt.xticks(size=15)
plt.yticks(size=15)
sns.despine();

# %%
y.describe()
# Out:
# count     1368.000000
# mean      2528.948099
# std       1984.954363
# min         67.000000
# 25%       1202.500000
# 50%       2090.500000
# 75%       3234.750000
# max      23425.000000
# Name: adq_daysonop, dtype: float64

# %%
plt.figure(figsize= [11,11])
plt.scatter(y,x)
plt.title("Time to adquisition by company category", size = 25)
plt.xlabel('Time in operation at acquisition, days', size = 20, labelpad = 15)
plt.ylabel('Category code              ', size = 20, rotation = 0, labelpad = 35)
plt.xticks(size=14)
plt.yticks(size=14)
ax = plt.gca()
ax.yaxis.set_label_coords(-0.06,0.97)
sns.despine();

# %%
3234/365
# Out:
# 8.860273972602739
